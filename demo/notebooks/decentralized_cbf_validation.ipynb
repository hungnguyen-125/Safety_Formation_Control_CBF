# %%
import numpy as np
import matplotlib.pyplot as plt
from safety_formation.controllers.cbf import DecentralizedCBF
from safety_formation.formation import Agent,Topology
from safety_formation.controllers.cbf import CBFTopology, DeadlockManager

# %% [markdown]
# ## Distributed ZCBF with slack variable

# %% [markdown]
# ### Static Obstacle Avoidance

# %%
gamma = 0.5
d_min = 0.5

# State format: [x, y, vx, vy]
x_agent0  = [0.0,  0.0,  0.0, 0.0]
x_obs0    = [5.0, -0.05, 0.0, 0.0]
x_target  = np.array([10.0, 0.0, 0.0, 0.0], dtype=float)

alpha_agent = 6.0
alpha_obs   = 0.0   # static obstacle

# --- Create agents using your Agent class ---
# f_target is not used in this experiment, so set it to zeros
agent = Agent(agent_id=1, x0=x_agent0, f_target=[0, 0, 0, 0], alpha=alpha_agent)
obs   = Agent(agent_id=2, x0=x_obs0,   f_target=[0, 0, 0, 0], alpha=alpha_obs)

all_agents = [agent, obs]

# Save initial states if you want history from t=0
for ag in all_agents:
    ag.save_history()

# --- Create topology ---
# Agent and obstacle are connected so CBF checks safety constraint between them
adj = np.array([
    [0, 1],
    [1, 0]
], dtype=float)

topology = Topology(num_agents=2, adjacency_matrix=adj)
topology.plot()

# --- Create CBF filter ---
cbf_filter = DecentralizedCBF(gamma=gamma, safety_dis=d_min)

# %%
# --- History buffers ---
robot_history = []
u_hat_history = []
u_safe_history = []
h_history = []
dist_history = []

T = 15.0
dt = 0.1
steps = int(T / dt)

for k in range(steps):
    # Current robot state
    x_agent = agent.state.flatten()

    # 1) Nominal controller (PD-like tracking to target)
    u_hat = -1.5 * (agent.pos.flatten() - x_target[0:2]) - 2.5 * agent.vel.flatten()
    
    neighbor_list = topology.get_neighbors(1)
    
    # 3. Filter via Decentralized CBF
    # Only solves the QP for agent 1 locally
    u_nom_i = u_hat.reshape(2, 1)
    u_apply = cbf_filter.compute_safe_control(agent, 1, all_agents, neighbor_list, u_nom_i)
    u_apply = u_apply.flatten()

    # 4) Update physics
    # robot moves with safe input
    agent.update_physics(u_apply, dt)

    # obstacle stays fixed
    obs.update_physics([0.0, 0.0], dt)

    # 5) Store histories
    robot_history.append(agent.state.flatten())
    u_hat_history.append(u_hat.copy())
    u_safe_history.append(u_apply.copy())

    # Optional diagnostics: current distance and barrier-like quantity
    dp = agent.pos - obs.pos
    dv = agent.vel - obs.vel
    dist = max(np.linalg.norm(dp), 1e-6)
    dist_history.append(dist)

    # Avoid sqrt of negative when dist < d_min
    margin = max(dist - d_min, 1e-6)
    term_safe_v = np.sqrt(2 * (agent.alpha + obs.alpha) * margin)
    h_val = term_safe_v + float((dp.T @ dv).item()) / dist
    
    h_history.append(h_val)

# --- Convert histories to arrays ---
robot_history = np.array(robot_history)
u_hat_history = np.array(u_hat_history)
u_safe_history = np.array(u_safe_history)
dist_history = np.array(dist_history)
h_history = np.array(h_history)
time = np.arange(steps) * dt

# --- Plotting ---
fig = plt.figure(figsize=(12, 12))

# 1. Trajectory
ax1 = plt.subplot(3, 1, 1)
ax1.plot(robot_history[:, 0], robot_history[:, 1], '-o', markersize=3, label='Robot path')
ax1.scatter([x_obs0[0]], [x_obs0[1]], color='red', s=100, label='Obstacle', zorder=5)
ax1.scatter([x_target[0]], [x_target[1]], color='green', s=100, marker='*', label='Target', zorder=5)
circle = plt.Circle((x_obs0[0], x_obs0[1]), d_min, color='red', fill=False, linestyle='--', label='Safety radius')
ax1.add_patch(circle)
ax1.set_title("Movement Trajectory (ZCBF Avoidance)")
ax1.set_xlabel("X (m)")
ax1.set_ylabel("Y (m)")
ax1.axis("equal")
ax1.grid(True)
ax1.legend()

# 2. Control signals
ax2 = plt.subplot(3, 2, 3)
ax2.plot(time, u_hat_history[:, 0], '--', color='gray', label='u_nom x')
ax2.plot(time, u_safe_history[:, 0], '-', color='blue', label='u_safe x')
ax2.set_title("X-axis Acceleration")
ax2.set_xlabel("Time (s)")
ax2.set_ylabel(r"$m/s^2$")
ax2.grid(True)
ax2.legend()

ax3 = plt.subplot(3, 2, 4)
ax3.plot(time, u_hat_history[:, 1], '--', color='gray', label='u_nom y')
ax3.plot(time, u_safe_history[:, 1], '-', color='green', label='u_safe y')
ax3.set_title("Y-axis Acceleration")
ax3.set_xlabel("Time (s)")
ax3.set_ylabel(r"$m/s^2$")
ax3.grid(True)
ax3.legend()

# 3. Distance to obstacle
ax4 = plt.subplot(3, 2, 5)
ax4.plot(time, dist_history, label='distance')
ax4.axhline(d_min, linestyle='--', color='red', label='d_min')
ax4.set_title("Distance to Obstacle")
ax4.set_xlabel("Time (s)")
ax4.set_ylabel("Distance (m)")
ax4.grid(True)
ax4.legend()

# 4. h_ij evolution
ax5 = plt.subplot(3, 2, 6)
ax5.plot(time, h_history, label=r'$h_{ij}$')
ax5.axhline(0.0, linestyle='--', color='red', label='0')
ax5.set_title("Barrier Function Value")
ax5.set_xlabel("Time (s)")
ax5.set_ylabel(r"$h_{ij}$")
ax5.grid(True)
ax5.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Collision Avoidance for Multi-agent System

# %%
# --- Simulation Configuration ---
N = 11
R_circle = 150
dt = 0.01
T_max = 40
steps = int(T_max / dt)

gamma = 0.001
d_min = 18.0
k1, k2 = 1 , 2.8

alpha_val = 10.0
beta_val = 20.0

# --- Create agents using your Agent class ---
agents_list = []

for i in range(N):
    angle = 2 * np.pi * i / N

    # Initial state: [x, y, vx, vy]
    x0 = [
        R_circle * np.cos(angle),
        R_circle * np.sin(angle),
        0.0,
        0.0
    ]

    # Opposite-side target
    target_pos = -np.array(x0[0:2]) - 10

    # f_target is not used in this experiment
    ag = Agent(
        agent_id=i + 1,
        x0=x0,
        f_target=[0.0, 0.0, 0.0, 0.0],
        alpha=alpha_val,
        beta=beta_val
    )

    # attach target for this experiment
    ag.target = target_pos.reshape(2,)
    agents_list.append(ag)

topology = CBFTopology(agents_list, d_min, gamma)
topology._compute_neighborhood_radii()

topology.plot(show_radius= False)

# --- CBF filter ---
cbf_filter = DecentralizedCBF(gamma=gamma,k= 1, safety_dis=d_min)

# %%
# --- History ---
history = [[] for _ in range(N)]
u_nom_hist = [[] for _ in range(N)]
u_safe_hist = [[] for _ in range(N)]

# --- Simulation Loop ---
for t in range(steps):
    
    u_nom_commands = {}
    u_safe_commands = {}

    topology.update_topology()
    
    # 1) Compute local safe control for each agent
    for agent_id in range(1, N + 1):
        current_agent = agents_list[agent_id - 1]   # because list is 0-based

        pos = current_agent.pos.flatten()
        vel = current_agent.vel.flatten()

        u_nom_i = -k1 * (pos - current_agent.target) - k2 * vel

        neighbor_list = topology.get_neighbors(agent_id)   # keep 1-based IDs

        u_safe_i = cbf_filter.compute_safe_control(
            agent_i=current_agent,
            agent_id=agent_id,
            all_agents=agents_list,        # list ordered by id
            neighbor_list=neighbor_list,
            u_nom_i=u_nom_i.reshape(2, 1)
        )

        u_nom_commands[agent_id] = u_nom_i.copy()
        u_safe_commands[agent_id] = u_safe_i.flatten()

    # 2) Update physics
    for agent_id in range(1, N + 1):
        ag = agents_list[agent_id - 1]

        ag.update_physics(u_safe_commands[agent_id], dt)

        history[agent_id - 1].append(ag.pos.flatten().copy())
        u_nom_hist[agent_id - 1].append(u_nom_commands[agent_id].copy())
        u_safe_hist[agent_id - 1].append(u_safe_commands[agent_id].copy())

# --- Convert history to arrays ---
history = [np.array(h) for h in history]
u_nom_hist = [np.array(h) for h in u_nom_hist]
u_safe_hist = [np.array(h) for h in u_safe_hist]

# --- Plot trajectories ---
plt.figure(figsize=(8, 8))
for i in range(N):
    traj = history[i]
    if len(traj) == 0:
        continue

    plt.plot(traj[:, 0], traj[:, 1], alpha=0.7, label=f'Agent {i+1}')
    plt.scatter(traj[0, 0], traj[0, 1], marker='o')
    plt.scatter(traj[-1, 0], traj[-1, 1], marker='x')
    plt.scatter(agents_list[i].target[0], agents_list[i].target[1], marker='*', s=120)

plt.title(f"Robot Position Swapping with Decentralized CBF (gamma={gamma}, d_min={d_min})")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.axis("equal")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Warning: Safety violated! Slack: 1.0570
# Warning: Safety violated! Slack: 3.9726
# Warning: Safety violated! Slack: 6.8552
# Warning: Safety violated! Slack: 0.1713
# Warning: Safety violated! Slack: 9.7063
# Warning: Safety violated! Slack: 2.2805
# Warning: Safety violated! Slack: 4.0383
# Warning: Safety violated! Slack: 12.5274
# Warning: Safety violated! Slack: 6.0909
# Warning: Safety violated! Slack: 7.8619
# Warning: Safety violated! Slack: 15.3201
# Warning: Safety violated! Slack: 9.8658
# Warning: Safety violated! Slack: 11.6436
# Warning: Safety violated! Slack: 18.0838
# Warning: Safety violated! Slack: 13.6055
# Warning: Safety violated! Slack: 15.3839
# Warning: Safety violated! Slack: 20.8183
# Warning: Safety violated! Slack: 17.3101
# Warning: Safety violated! Slack: 19.0834
# Warning: Safety violated! Slack: 23.5235
# Warning: Safety violated! Slack: 20.9798
# Warning: Safety violated! Slack: 22.7424
# Warning: Safety violated! Slack: 26.1990
# Warning: Safety violated! Slack: 24.6112
# Warning: Safety violated! Slack: 26.3615
# Warning: Safety violated! Slack: 28.8448
# Warning: Safety violated! Slack: 28.2028
# Warning: Safety violated! Slack: 29.9411
# Warning: Safety violated! Slack: 31.4605
# Warning: Safety violated! Slack: 31.7552
# Warning: Safety violated! Slack: 33.4816
# Warning: Safety violated! Slack: 34.0461
# Warning: Safety violated! Slack: 35.2686
# Warning: Safety violated! Slack: 36.9835
# Warning: Safety violated! Slack: 36.6011
# Warning: Safety violated! Slack: 38.7435
# Warning: Safety violated! Slack: 40.4471
# Warning: Safety violated! Slack: 39.1223
# Warning: Safety violated! Slack: 42.1803
# Warning: Safety violated! Slack: 43.8729
# Warning: Safety violated! Slack: 41.5994
# Warning: Safety violated! Slack: 45.5793
# Warning: Safety violated! Slack: 47.2611
# Warning: Safety violated! Slack: 44.0329
# Warning: Safety violated! Slack: 48.9410
# Warning: Safety violated! Slack: 50.6122
# Warning: Safety violated! Slack: 46.4233
# Warning: Safety violated! Slack: 52.2656
# Warning: Safety violated! Slack: 53.9266
# Warning: Safety violated! Slack: 48.7707
# Warning: Safety violated! Slack: 55.5536
# Warning: Safety violated! Slack: 57.2045
# Warning: Safety violated! Slack: 51.0757
# Warning: Safety violated! Slack: 58.8052
# Warning: Safety violated! Slack: 60.4463
# Warning: Safety violated! Slack: 53.3351
# Warning: Safety violated! Slack: 62.0208
# Warning: Safety violated! Slack: 63.6451
# Warning: Safety violated! Slack: 55.5477
# Warning: Safety violated! Slack: 65.1996
# Warning: Safety violated! Slack: 66.7985
# Warning: Safety violated! Slack: 57.7140
# Warning: Safety violated! Slack: 68.3330
# Warning: Safety violated! Slack: 69.9069
# Warning: Safety violated! Slack: 59.8392
# Warning: Safety violated! Slack: 71.4216
# Warning: Safety violated! Slack: 72.9708
# Warning: Safety violated! Slack: 61.9270
# Warning: Safety violated! Slack: 1.4824
# Warning: Safety violated! Slack: 74.4657
# Warning: Safety violated! Slack: 75.9905
# Warning: Safety violated! Slack: 63.9645
# Warning: Safety violated! Slack: 4.1902
# Warning: Safety violated! Slack: 77.4657
# Warning: Safety violated! Slack: 78.9666
# Warning: Safety violated! Slack: 65.9522
# Warning: Safety violated! Slack: 6.8453
# Warning: Safety violated! Slack: 80.4221
# Warning: Safety violated! Slack: 81.8993
# Warning: Safety violated! Slack: 67.8911
# Warning: Safety violated! Slack: 9.4486
# Warning: Safety violated! Slack: 82.8802
# Warning: Safety violated! Slack: 84.2883
# Warning: Safety violated! Slack: 69.7818
# Warning: Safety violated! Slack: 12.0009
# Warning: Safety violated! Slack: 84.6781
# Warning: Safety violated! Slack: 86.0817
# Warning: Safety violated! Slack: 71.6253
# Warning: Safety violated! Slack: 14.5031
# Warning: Safety violated! Slack: 86.4285
# Warning: Safety violated! Slack: 87.8326
# Warning: Safety violated! Slack: 73.4221
# Warning: Safety violated! Slack: 16.9561
# Warning: Safety violated! Slack: 88.1314
# Warning: Safety violated! Slack: 89.5416
# Warning: Safety violated! Slack: 75.1730
# Warning: Safety violated! Slack: 19.3606
# Warning: Safety violated! Slack: 89.7873
# Warning: Safety violated! Slack: 91.2093
# Warning: Safety violated! Slack: 76.8787
# Warning: Safety violated! Slack: 21.7174
# Warning: Safety violated! Slack: 91.4133
# Warning: Safety violated! Slack: 92.8364
# Warning: Safety violated! Slack: 78.5398
# Warning: Safety violated! Slack: 24.0273
# Warning: Safety violated! Slack: 93.0139
# Warning: Safety violated! Slack: 94.4234
# Warning: Safety violated! Slack: 80.1571
# Warning: Safety violated! Slack: 26.2910
# Warning: Safety violated! Slack: 94.5831
# Warning: Safety violated! Slack: 95.9708
# Warning: Safety violated! Slack: 81.7310
# Warning: Safety violated! Slack: 28.5093
# Warning: Safety violated! Slack: 96.1216
# Warning: Safety violated! Slack: 97.4792
# Warning: Safety violated! Slack: 83.2622
# Warning: Safety violated! Slack: 30.6829
# Warning: Safety violated! Slack: 97.6299
# Warning: Safety violated! Slack: 98.9491
# Warning: Safety violated! Slack: 84.7514
# Warning: Safety violated! Slack: 32.8124
# Warning: Safety violated! Slack: 99.1088
# Warning: Safety violated! Slack: 100.3811
# Warning: Safety violated! Slack: 86.1991
# Warning: Safety violated! Slack: 34.8985
# Warning: Safety violated! Slack: 100.5587
# Warning: Safety violated! Slack: 101.7882
# Warning: Safety violated! Slack: 87.6058
# Warning: Safety violated! Slack: 36.9419
# Warning: Safety violated! Slack: 101.9801
# Warning: Safety violated! Slack: 103.1842
# Warning: Safety violated! Slack: 88.9721
# Warning: Safety violated! Slack: 38.9432
# Warning: Safety violated! Slack: 103.3735
# Warning: Safety violated! Slack: 104.5524
# Warning: Safety violated! Slack: 90.2985
# Warning: Safety violated! Slack: 40.9031
# Warning: Safety violated! Slack: 104.7394
# Warning: Safety violated! Slack: 105.8932
# Warning: Safety violated! Slack: 91.5856
# Warning: Safety violated! Slack: 42.8220
# Warning: Safety violated! Slack: 106.0782
# Warning: Safety violated! Slack: 107.2072
# Warning: Safety violated! Slack: 92.8338
# Warning: Safety violated! Slack: 44.7007
# Warning: Safety violated! Slack: 107.3904
# Warning: Safety violated! Slack: 108.4947
# Warning: Safety violated! Slack: 93.9756
# Warning: Safety violated! Slack: 46.5397
# Warning: Safety violated! Slack: 108.6764
# Warning: Safety violated! Slack: 109.7564
# Warning: Safety violated! Slack: 94.9702
# Warning: Safety violated! Slack: 48.3396
# Warning: Safety violated! Slack: 109.9369
# Warning: Safety violated! Slack: 110.9926
# Warning: Safety violated! Slack: 0.5645
# Warning: Safety violated! Slack: 95.9414
# Warning: Safety violated! Slack: 50.1010
# Warning: Safety violated! Slack: 111.1721
# Warning: Safety violated! Slack: 112.2039
# Warning: Safety violated! Slack: 1.3317
# Warning: Safety violated! Slack: 96.8913
# Warning: Safety violated! Slack: 51.8243
# Warning: Safety violated! Slack: 112.3825
# Warning: Safety violated! Slack: 113.3906
# Warning: Safety violated! Slack: 2.0681
# Warning: Safety violated! Slack: 97.8208
# Warning: Safety violated! Slack: 53.5102
# Warning: Safety violated! Slack: 113.5686
# Warning: Safety violated! Slack: 114.5531
# Warning: Safety violated! Slack: 2.7739
# Warning: Safety violated! Slack: 98.7301
# Warning: Safety violated! Slack: 55.1590
# Warning: Safety violated! Slack: 114.7308
# Warning: Safety violated! Slack: 115.6920
# Warning: Safety violated! Slack: 3.4495
# Warning: Safety violated! Slack: 99.6195
# Warning: Safety violated! Slack: 56.7713
# Warning: Safety violated! Slack: 115.8695
# Warning: Safety violated! Slack: 116.8022
# Warning: Safety violated! Slack: 4.0950
# Warning: Safety violated! Slack: 100.4893
# Warning: Safety violated! Slack: 58.3476
# Warning: Safety violated! Slack: 116.9810
# Warning: Safety violated! Slack: 117.8830
# Warning: Safety violated! Slack: 4.7109
# Warning: Safety violated! Slack: 101.3398
# Warning: Safety violated! Slack: 59.8882
# Warning: Safety violated! Slack: 118.0634
# Warning: Safety violated! Slack: 118.9302
# Warning: Safety violated! Slack: 5.2973
# Warning: Safety violated! Slack: 102.1711
# Warning: Safety violated! Slack: 61.3936
# Warning: Safety violated! Slack: 119.1126
# Warning: Safety violated! Slack: 119.9448
# Warning: Safety violated! Slack: 5.8547
# Warning: Safety violated! Slack: 102.9835
# Warning: Safety violated! Slack: 62.8644
# Warning: Safety violated! Slack: 120.1294
# Warning: Safety violated! Slack: 120.9275
# Warning: Safety violated! Slack: 6.3833
# Warning: Safety violated! Slack: 103.7773
# Warning: Safety violated! Slack: 64.3008
# Warning: Safety violated! Slack: 121.1147
# Warning: Safety violated! Slack: 121.8790
# Warning: Safety violated! Slack: 6.8834
# Warning: Safety violated! Slack: 104.5527
# Warning: Safety violated! Slack: 65.7033
# Warning: Safety violated! Slack: 122.0691
# Warning: Safety violated! Slack: 122.8001
# Warning: Safety violated! Slack: 7.3553
# Warning: Safety violated! Slack: 105.3099
# Warning: Safety violated! Slack: 67.0724
# Warning: Safety violated! Slack: 122.9936
# Warning: Safety violated! Slack: 123.6915
# Warning: Safety violated! Slack: 7.7993
# Warning: Safety violated! Slack: 106.0491
# Warning: Safety violated! Slack: 68.4083
# Warning: Safety violated! Slack: 123.8887
# Warning: Safety violated! Slack: 124.5540
# Warning: Safety violated! Slack: 8.2156
# Warning: Safety violated! Slack: 106.7707
# Warning: Safety violated! Slack: 69.7116
# Warning: Safety violated! Slack: 124.7552
# Warning: Safety violated! Slack: 125.3882
# Warning: Safety violated! Slack: 8.6045
# Warning: Safety violated! Slack: 107.4747
# Warning: Safety violated! Slack: 70.9825
# Warning: Safety violated! Slack: 125.5938
# Warning: Safety violated! Slack: 126.1948
# Warning: Safety violated! Slack: 8.9662
# Warning: Safety violated! Slack: 108.1615
# Warning: Safety violated! Slack: 72.2214
# Warning: Safety violated! Slack: 126.4051
# Warning: Safety violated! Slack: 126.9745
# Warning: Safety violated! Slack: 9.3011
# Warning: Safety violated! Slack: 108.8312
# Warning: Safety violated! Slack: 73.4288
# Warning: Safety violated! Slack: 127.1899
# Warning: Safety violated! Slack: 127.7278
# Warning: Safety violated! Slack: 9.6092
# Warning: Safety violated! Slack: 109.4841
# Warning: Safety violated! Slack: 74.6049
# Warning: Safety violated! Slack: 127.9487
# Warning: Safety violated! Slack: 128.4554
# Warning: Safety violated! Slack: 9.8909
# Warning: Safety violated! Slack: 110.1203
# Warning: Safety violated! Slack: 75.7504
# Warning: Safety violated! Slack: 0.5658
# Warning: Safety violated! Slack: 128.6822
# Warning: Safety violated! Slack: 129.1580
# Warning: Safety violated! Slack: 10.1463
# Warning: Safety violated! Slack: 110.7401
# Warning: Safety violated! Slack: 76.8673
# Warning: Safety violated! Slack: 1.0288
# Warning: Safety violated! Slack: 129.3910
# Warning: Safety violated! Slack: 129.8361
# Warning: Safety violated! Slack: 10.3757
# Warning: Safety violated! Slack: 111.3436
# Warning: Safety violated! Slack: 77.9557
# Warning: Safety violated! Slack: 1.4731
# Warning: Safety violated! Slack: 130.0757
# Warning: Safety violated! Slack: 130.4903
# Warning: Safety violated! Slack: 10.5794
# Warning: Safety violated! Slack: 111.9311
# Warning: Safety violated! Slack: 79.0159
# Warning: Safety violated! Slack: 1.8987
# Warning: Safety violated! Slack: 130.7368
# Warning: Safety violated! Slack: 131.1211
# Warning: Safety violated! Slack: 10.7574
# Warning: Safety violated! Slack: 112.5028
# Warning: Safety violated! Slack: 80.0480
# Warning: Safety violated! Slack: 2.3060
# Warning: Safety violated! Slack: 131.3750
# Warning: Safety violated! Slack: 131.7292
# Warning: Safety violated! Slack: 10.9101
# Warning: Safety violated! Slack: 113.0588
# Warning: Safety violated! Slack: 81.0522
# Warning: Safety violated! Slack: 2.6951
# Warning: Safety violated! Slack: 131.9908
# Warning: Safety violated! Slack: 132.3151
# Warning: Safety violated! Slack: 11.0376
# Warning: Safety violated! Slack: 113.5994
# Warning: Safety violated! Slack: 82.0286
# Warning: Safety violated! Slack: 3.0662
# Warning: Safety violated! Slack: 132.5847
# Warning: Safety violated! Slack: 132.8792
# Warning: Safety violated! Slack: 11.1400
# Warning: Safety violated! Slack: 114.1246
# Warning: Safety violated! Slack: 82.9774
# Warning: Safety violated! Slack: 3.4196
# Warning: Safety violated! Slack: 133.1572
# Warning: Safety violated! Slack: 133.4221
# Warning: Safety violated! Slack: 11.2177
# Warning: Safety violated! Slack: 114.6348
# Warning: Safety violated! Slack: 83.8988
# Warning: Safety violated! Slack: 3.7553
# Warning: Safety violated! Slack: 133.7089
# Warning: Safety violated! Slack: 133.9444
# Warning: Safety violated! Slack: 11.2707
# Warning: Safety violated! Slack: 115.1301
# Warning: Safety violated! Slack: 84.7928
# Warning: Safety violated! Slack: 4.0735
# Warning: Safety violated! Slack: 134.2402
# Warning: Safety violated! Slack: 134.4465
# Warning: Safety violated! Slack: 11.2992
# Warning: Safety violated! Slack: 115.6107
# Warning: Safety violated! Slack: 85.6598
# Warning: Safety violated! Slack: 4.3745
# Warning: Safety violated! Slack: 134.7517
# Warning: Safety violated! Slack: 134.9289
# Warning: Safety violated! Slack: 11.3034
# Warning: Safety violated! Slack: 116.0767
# Warning: Safety violated! Slack: 86.4999
# Warning: Safety violated! Slack: 4.6584
# Warning: Safety violated! Slack: 135.2438
# Warning: Safety violated! Slack: 135.3921
# Warning: Safety violated! Slack: 11.2835
# Warning: Safety violated! Slack: 116.5283
# Warning: Safety violated! Slack: 87.3131
# Warning: Safety violated! Slack: 4.9254
# Warning: Safety violated! Slack: 135.7170
# Warning: Safety violated! Slack: 135.8365
# Warning: Safety violated! Slack: 11.2396
# Warning: Safety violated! Slack: 116.9657
# Warning: Safety violated! Slack: 88.0997
# Warning: Safety violated! Slack: 5.1756
# Warning: Safety violated! Slack: 136.1717
# Warning: Safety violated! Slack: 136.2627
# Warning: Safety violated! Slack: 11.1719
# Warning: Safety violated! Slack: 117.3890
# Warning: Safety violated! Slack: 88.8597
# Warning: Safety violated! Slack: 5.4092
# Warning: Safety violated! Slack: 136.6085
# Warning: Safety violated! Slack: 136.6710
# Warning: Safety violated! Slack: 11.0805
# Warning: Safety violated! Slack: 117.7985
# Warning: Safety violated! Slack: 89.5935
# Warning: Safety violated! Slack: 5.6264
# Warning: Safety violated! Slack: 137.0277
# Warning: Safety violated! Slack: 137.0619
# Warning: Safety violated! Slack: 10.9655
# Warning: Safety violated! Slack: 118.1943
# Warning: Safety violated! Slack: 90.3010
# Warning: Safety violated! Slack: 5.8274
# Warning: Safety violated! Slack: 137.4298
# Warning: Safety violated! Slack: 137.4358
# Warning: Safety violated! Slack: 10.8272
# Warning: Safety violated! Slack: 118.5765
# Warning: Safety violated! Slack: 90.9826
# Warning: Safety violated! Slack: 6.0123
# Warning: Safety violated! Slack: 137.8151
# Warning: Safety violated! Slack: 137.7932
# Warning: Safety violated! Slack: 10.6657
# Warning: Safety violated! Slack: 118.9453
# Warning: Safety violated! Slack: 91.6382
# Warning: Safety violated! Slack: 6.1812
# Warning: Safety violated! Slack: 138.1842
# Warning: Safety violated! Slack: 138.1344
# Warning: Safety violated! Slack: 10.4810
# Warning: Safety violated! Slack: 119.3009
# Warning: Safety violated! Slack: 92.2680
# Warning: Safety violated! Slack: 6.3343
# Warning: Safety violated! Slack: 138.5374
# Warning: Safety violated! Slack: 138.4599
# Warning: Safety violated! Slack: 10.2734
# Warning: Safety violated! Slack: 119.6434
# Warning: Safety violated! Slack: 92.8723
# Warning: Safety violated! Slack: 6.4718
# Warning: Safety violated! Slack: 138.8752
# Warning: Safety violated! Slack: 138.7701
# Warning: Safety violated! Slack: 10.0429
# Warning: Safety violated! Slack: 119.9729
# Warning: Safety violated! Slack: 93.4511
# Warning: Safety violated! Slack: 6.5938
# Warning: Safety violated! Slack: 139.1978
# Warning: Safety violated! Slack: 139.0654
# Warning: Safety violated! Slack: 9.7896
# Warning: Safety violated! Slack: 120.2897
# Warning: Safety violated! Slack: 94.0046
# Warning: Safety violated! Slack: 6.7005
# Warning: Safety violated! Slack: 139.5057
# Warning: Safety violated! Slack: 139.3461
# Warning: Safety violated! Slack: 9.5138
# Warning: Safety violated! Slack: 120.5938
# Warning: Safety violated! Slack: 94.5329
# Warning: Safety violated! Slack: 6.7919
# Warning: Safety violated! Slack: 139.7993
# Warning: Safety violated! Slack: 139.6126
# Warning: Safety violated! Slack: 9.2154
# Warning: Safety violated! Slack: 120.8855
# Warning: Safety violated! Slack: 95.0361
# Warning: Safety violated! Slack: 6.8684
# Warning: Safety violated! Slack: 140.0790
# Warning: Safety violated! Slack: 139.8653
# Warning: Safety violated! Slack: 8.8947
# Warning: Safety violated! Slack: 121.1647
# Warning: Safety violated! Slack: 95.5145
# Warning: Safety violated! Slack: 6.9299
# Warning: Safety violated! Slack: 140.3450
# Warning: Safety violated! Slack: 140.1047
# Warning: Safety violated! Slack: 8.5517
# Warning: Safety violated! Slack: 121.4318
# Warning: Safety violated! Slack: 95.9680
# Warning: Safety violated! Slack: 6.9766
# Warning: Safety violated! Slack: 140.5978
# Warning: Safety violated! Slack: 140.3309
# Warning: Safety violated! Slack: 8.1865
# Warning: Safety violated! Slack: 121.6868
# Warning: Safety violated! Slack: 96.3970
# Warning: Safety violated! Slack: 7.0088
# Warning: Safety violated! Slack: 140.8376
# Warning: Safety violated! Slack: 140.5444
# Warning: Safety violated! Slack: 7.7992
# Warning: Safety violated! Slack: 121.9298
# Warning: Safety violated! Slack: 96.8014
# Warning: Safety violated! Slack: 7.0264
# Warning: Safety violated! Slack: 141.0649
# Warning: Safety violated! Slack: 140.7456
# Warning: Safety violated! Slack: 7.3900
# Warning: Safety violated! Slack: 122.1611
# Warning: Safety violated! Slack: 97.1815
# Warning: Safety violated! Slack: 7.0297
# Warning: Safety violated! Slack: 141.2800
# Warning: Safety violated! Slack: 140.9348
# Warning: Safety violated! Slack: 6.9589
# Warning: Safety violated! Slack: 122.3807
# Warning: Safety violated! Slack: 97.5373
# Warning: Safety violated! Slack: 7.0187
# Warning: Safety violated! Slack: 141.4832
# Warning: Safety violated! Slack: 141.1122
# Warning: Safety violated! Slack: 6.5060
# Warning: Safety violated! Slack: 122.5887
# Warning: Safety violated! Slack: 97.8690
# Warning: Safety violated! Slack: 6.9937
# Warning: Safety violated! Slack: 141.6748
# Warning: Safety violated! Slack: 141.2783
# Warning: Safety violated! Slack: 6.0315
# Warning: Safety violated! Slack: 122.7853
# Warning: Safety violated! Slack: 98.1768
# Warning: Safety violated! Slack: 6.9547
# Warning: Safety violated! Slack: 141.8552
# Warning: Safety violated! Slack: 141.4334
# Warning: Safety violated! Slack: 5.5353
# Warning: Safety violated! Slack: 122.9707
# Warning: Safety violated! Slack: 98.4607
# Warning: Safety violated! Slack: 6.9019
# Warning: Safety violated! Slack: 142.0246
# Warning: Safety violated! Slack: 141.5778
# Warning: Safety violated! Slack: 5.0177
# Warning: Safety violated! Slack: 123.1449
# Warning: Safety violated! Slack: 98.7208
# Warning: Safety violated! Slack: 6.8353
# Warning: Safety violated! Slack: 142.1834
# Warning: Safety violated! Slack: 141.7117
# Warning: Safety violated! Slack: 4.4786
# Warning: Safety violated! Slack: 123.3080
# Warning: Safety violated! Slack: 98.9574
# Warning: Safety violated! Slack: 6.7552
# Warning: Safety violated! Slack: 142.3318
# Warning: Safety violated! Slack: 141.8356
# Warning: Safety violated! Slack: 3.9182
# Warning: Safety violated! Slack: 123.4603
# Warning: Safety violated! Slack: 99.1705
# Warning: Safety violated! Slack: 6.6616
# Warning: Safety violated! Slack: 142.4702
# Warning: Safety violated! Slack: 141.9498
# Warning: Safety violated! Slack: 3.3365
# Warning: Safety violated! Slack: 123.6017
# Warning: Safety violated! Slack: 99.3603
# Warning: Safety violated! Slack: 6.5546
# Warning: Safety violated! Slack: 142.5988
# Warning: Safety violated! Slack: 142.0544
# Warning: Safety violated! Slack: 2.7336
# Warning: Safety violated! Slack: 123.7325
# Warning: Safety violated! Slack: 99.5268
# Warning: Safety violated! Slack: 6.4344
# Warning: Safety violated! Slack: 142.7180
# Warning: Safety violated! Slack: 142.1499
# Warning: Safety violated! Slack: 2.1096
# Warning: Safety violated! Slack: 123.8527
# Warning: Safety violated! Slack: 99.6703
# Warning: Safety violated! Slack: 6.3012
# Warning: Safety violated! Slack: 142.8280
# Warning: Safety violated! Slack: 142.2366
# Warning: Safety violated! Slack: 1.4646
# Warning: Safety violated! Slack: 123.9624
# Warning: Safety violated! Slack: 99.7907
# Warning: Safety violated! Slack: 6.1549
# Warning: Safety violated! Slack: 142.9291
# Warning: Safety violated! Slack: 142.3146
# Warning: Safety violated! Slack: 0.7985
# Warning: Safety violated! Slack: 124.0619
# Warning: Safety violated! Slack: 99.8883
# Warning: Safety violated! Slack: 5.9957
# Warning: Safety violated! Slack: 143.0216
# Warning: Safety violated! Slack: 142.3844
# Warning: Safety violated! Slack: 0.1116
# Warning: Safety violated! Slack: 124.1511
# Warning: Safety violated! Slack: 99.9632
# Warning: Safety violated! Slack: 5.8238
# Warning: Safety violated! Slack: 143.1057
# Warning: Safety violated! Slack: 142.4461
# Warning: Safety violated! Slack: 124.2302
# Warning: Safety violated! Slack: 100.0155
# Warning: Safety violated! Slack: 5.6392
# Warning: Safety violated! Slack: 143.1817
# Warning: Safety violated! Slack: 142.5001
# Warning: Safety violated! Slack: 124.3022
# Warning: Safety violated! Slack: 100.0452
# Warning: Safety violated! Slack: 5.4421
# Warning: Safety violated! Slack: 143.2499
# Warning: Safety violated! Slack: 142.5467
# Warning: Safety violated! Slack: 124.3678
# Warning: Safety violated! Slack: 100.0526
# Warning: Safety violated! Slack: 5.2325
# Warning: Safety violated! Slack: 143.3105
# Warning: Safety violated! Slack: 142.5860
# Warning: Safety violated! Slack: 124.4273
# Warning: Safety violated! Slack: 100.0377
# Warning: Safety violated! Slack: 5.0106
# Warning: Safety violated! Slack: 143.3637
# Warning: Safety violated! Slack: 142.6182
# Warning: Safety violated! Slack: 124.4808
# Warning: Safety violated! Slack: 100.0006
# Warning: Safety violated! Slack: 4.7764
# Warning: Safety violated! Slack: 143.4099
# Warning: Safety violated! Slack: 142.6437
# Warning: Safety violated! Slack: 124.5286
# Warning: Safety violated! Slack: 99.9415
# Warning: Safety violated! Slack: 4.5302
# Warning: Safety violated! Slack: 143.4492
# Warning: Safety violated! Slack: 142.6627
# Warning: Safety violated! Slack: 124.5709
# Warning: Safety violated! Slack: 99.8605
# Warning: Safety violated! Slack: 4.2718
# Warning: Safety violated! Slack: 143.4819
# Warning: Safety violated! Slack: 142.6753
# Warning: Safety violated! Slack: 124.6078
# Warning: Safety violated! Slack: 99.7577
# Warning: Safety violated! Slack: 4.0016
# Warning: Safety violated! Slack: 143.5083
# Warning: Safety violated! Slack: 142.6817
# Warning: Safety violated! Slack: 124.6395
# Warning: Safety violated! Slack: 99.6332
# Warning: Safety violated! Slack: 3.7195
# Warning: Safety violated! Slack: 143.5285
# Warning: Safety violated! Slack: 142.6823
# Warning: Safety violated! Slack: 124.6662
# Warning: Safety violated! Slack: 99.4871
# Warning: Safety violated! Slack: 3.4257
# Warning: Safety violated! Slack: 143.5428
# Warning: Safety violated! Slack: 142.6771
# Warning: Safety violated! Slack: 124.6880
# Warning: Safety violated! Slack: 99.3195
# Warning: Safety violated! Slack: 3.1203
# Warning: Safety violated! Slack: 143.5514
# Warning: Safety violated! Slack: 142.6664
# Warning: Safety violated! Slack: 124.7053
# Warning: Safety violated! Slack: 99.1306
# Warning: Safety violated! Slack: 2.8033
# Warning: Safety violated! Slack: 143.5545
# Warning: Safety violated! Slack: 142.6504
# Warning: Safety violated! Slack: 124.7180
# Warning: Safety violated! Slack: 98.9204
# Warning: Safety violated! Slack: 2.4748
# Warning: Safety violated! Slack: 143.5524
# Warning: Safety violated! Slack: 142.6293
# Warning: Safety violated! Slack: 124.7264
# Warning: Safety violated! Slack: 98.6891
# Warning: Safety violated! Slack: 2.1349
# Warning: Safety violated! Slack: 143.5453
# Warning: Safety violated! Slack: 142.6032
# Warning: Safety violated! Slack: 124.7305
# Warning: Safety violated! Slack: 98.4367
# Warning: Safety violated! Slack: 1.7838
# Warning: Safety violated! Slack: 143.5334
# Warning: Safety violated! Slack: 142.5724
# Warning: Safety violated! Slack: 124.7307
# Warning: Safety violated! Slack: 98.1634
# Warning: Safety violated! Slack: 1.4215
# Warning: Safety violated! Slack: 143.5168
# Warning: Safety violated! Slack: 142.5369
# Warning: Safety violated! Slack: 124.7269
# Warning: Safety violated! Slack: 97.8693
# Warning: Safety violated! Slack: 1.0480
# Warning: Safety violated! Slack: 143.4959
# Warning: Safety violated! Slack: 142.4971
# Warning: Safety violated! Slack: 124.7194
# Warning: Safety violated! Slack: 97.5544
# Warning: Safety violated! Slack: 0.6635
# Warning: Safety violated! Slack: 143.4707
# Warning: Safety violated! Slack: 142.4530
# Warning: Safety violated! Slack: 124.7083
# Warning: Safety violated! Slack: 97.2190
# Warning: Safety violated! Slack: 0.2680
# Warning: Safety violated! Slack: 143.4416
# Warning: Safety violated! Slack: 142.4049
# Warning: Safety violated! Slack: 124.6937
# Warning: Safety violated! Slack: 96.8630
# Warning: Safety violated! Slack: 143.4086
# Warning: Safety violated! Slack: 142.3528
# Warning: Safety violated! Slack: 124.6757
# Warning: Safety violated! Slack: 96.4871
# Warning: Safety violated! Slack: 143.3720
# Warning: Safety violated! Slack: 142.2970
# Warning: Safety violated! Slack: 124.6545
# Warning: Safety violated! Slack: 96.0922
# Warning: Safety violated! Slack: 143.3320
# Warning: Safety violated! Slack: 142.2376
# Warning: Safety violated! Slack: 124.6301
# Warning: Safety violated! Slack: 95.6785
# Warning: Safety violated! Slack: 143.2887
# Warning: Safety violated! Slack: 142.1747
# Warning: Safety violated! Slack: 124.6027
# Warning: Safety violated! Slack: 95.2459
# Warning: Safety violated! Slack: 143.2424
# Warning: Safety violated! Slack: 142.1086
# Warning: Safety violated! Slack: 124.5724
# Warning: Safety violated! Slack: 94.7947
# Warning: Safety violated! Slack: 143.1930
# Warning: Safety violated! Slack: 142.0392
# Warning: Safety violated! Slack: 124.5394
# Warning: Safety violated! Slack: 94.3247
# Warning: Safety violated! Slack: 143.1409
# Warning: Safety violated! Slack: 141.9669
# Warning: Safety violated! Slack: 124.5036
# Warning: Safety violated! Slack: 93.8362
# Warning: Safety violated! Slack: 143.0862
# Warning: Safety violated! Slack: 141.8916
# Warning: Safety violated! Slack: 124.4652
# Warning: Safety violated! Slack: 93.3292
# Warning: Safety violated! Slack: 143.0290
# Warning: Safety violated! Slack: 141.8137
# Warning: Safety violated! Slack: 124.4242
# Warning: Safety violated! Slack: 92.8037
# Warning: Safety violated! Slack: 142.9694
# Warning: Safety violated! Slack: 141.7330
# Warning: Safety violated! Slack: 124.3809
# Warning: Safety violated! Slack: 92.2599
# Warning: Safety violated! Slack: 142.9076
# Warning: Safety violated! Slack: 141.6499
# Warning: Safety violated! Slack: 124.3353
# Warning: Safety violated! Slack: 91.6977
# Warning: Safety violated! Slack: 142.8438
# Warning: Safety violated! Slack: 141.5645
# Warning: Safety violated! Slack: 124.2873
# Warning: Safety violated! Slack: 91.1173
# Warning: Safety violated! Slack: 142.7780
# Warning: Safety violated! Slack: 141.4767
# Warning: Safety violated! Slack: 124.2373
# Warning: Safety violated! Slack: 90.5186
# Warning: Safety violated! Slack: 142.7104
# Warning: Safety violated! Slack: 141.3869
# Warning: Safety violated! Slack: 124.1851
# Warning: Safety violated! Slack: 89.9018
# Warning: Safety violated! Slack: 142.6411
# Warning: Safety violated! Slack: 141.2950
# Warning: Safety violated! Slack: 124.1310
# Warning: Safety violated! Slack: 89.2669
# Warning: Safety violated! Slack: 142.5703
# Warning: Safety violated! Slack: 141.2012
# Warning: Safety violated! Slack: 124.0749
# Warning: Safety violated! Slack: 88.6139
# Warning: Safety violated! Slack: 142.4980
# Warning: Safety violated! Slack: 141.1056
# Warning: Safety violated! Slack: 124.0169
# Warning: Safety violated! Slack: 87.9429
# Warning: Safety violated! Slack: 142.4245
# Warning: Safety violated! Slack: 141.0084
# Warning: Safety violated! Slack: 123.9571
# Warning: Safety violated! Slack: 87.2540
# Warning: Safety violated! Slack: 142.3497
# Warning: Safety violated! Slack: 140.9095
# Warning: Safety violated! Slack: 123.8957
# Warning: Safety violated! Slack: 86.5471
# Warning: Safety violated! Slack: 142.2738
# Warning: Safety violated! Slack: 140.8091
# Warning: Safety violated! Slack: 123.8325
# Warning: Safety violated! Slack: 85.8224
# Warning: Safety violated! Slack: 142.1970
# Warning: Safety violated! Slack: 140.7074
# Warning: Safety violated! Slack: 123.7678
# Warning: Safety violated! Slack: 85.0799
# Warning: Safety violated! Slack: 142.1193
# Warning: Safety violated! Slack: 140.6043
# Warning: Safety violated! Slack: 123.7015
# Warning: Safety violated! Slack: 84.3195
# Warning: Safety violated! Slack: 142.0408
# Warning: Safety violated! Slack: 140.5001
# Warning: Safety violated! Slack: 123.6337
# Warning: Safety violated! Slack: 83.5414
# Warning: Safety violated! Slack: 141.9616
# Warning: Safety violated! Slack: 140.3947
# Warning: Safety violated! Slack: 123.5645
# Warning: Safety violated! Slack: 82.7456
# Warning: Safety violated! Slack: 141.8819
# Warning: Safety violated! Slack: 140.2883
# Warning: Safety violated! Slack: 123.4940
# Warning: Safety violated! Slack: 81.9321
# Warning: Safety violated! Slack: 141.8017
# Warning: Safety violated! Slack: 140.1810
# Warning: Safety violated! Slack: 123.4221
# Warning: Safety violated! Slack: 81.1009
# Warning: Safety violated! Slack: 141.7210
# Warning: Safety violated! Slack: 140.0728
# Warning: Safety violated! Slack: 123.3490
# Warning: Safety violated! Slack: 80.2521
# Warning: Safety violated! Slack: 141.6401
# Warning: Safety violated! Slack: 139.9638
# Warning: Safety violated! Slack: 123.2746
# Warning: Safety violated! Slack: 79.3857
# Warning: Safety violated! Slack: 141.5590
# Warning: Safety violated! Slack: 139.8541
# Warning: Safety violated! Slack: 123.1991
# Warning: Safety violated! Slack: 78.5017
# Warning: Safety violated! Slack: 141.4777
# Warning: Safety violated! Slack: 139.7438
# Warning: Safety violated! Slack: 123.1225
# Warning: Safety violated! Slack: 77.6001
# Warning: Safety violated! Slack: 141.3964
# Warning: Safety violated! Slack: 139.6329
# Warning: Safety violated! Slack: 123.0449
# Warning: Safety violated! Slack: 76.6810
# Warning: Safety violated! Slack: 141.3150
# Warning: Safety violated! Slack: 139.5216
# Warning: Safety violated! Slack: 122.9662
# Warning: Safety violated! Slack: 75.7444
# Warning: Safety violated! Slack: 141.2338
# Warning: Safety violated! Slack: 139.4098
# Warning: Safety violated! Slack: 122.8866
# Warning: Safety violated! Slack: 74.7903
# Warning: Safety violated! Slack: 141.1528
# Warning: Safety violated! Slack: 139.2964
# Warning: Safety violated! Slack: 122.8060
# Warning: Safety violated! Slack: 73.8187
# Warning: Safety violated! Slack: 141.0720
# Warning: Safety violated! Slack: 139.1802
# Warning: Safety violated! Slack: 122.7246
# Warning: Safety violated! Slack: 72.8296
# Warning: Safety violated! Slack: 140.9915
# Warning: Safety violated! Slack: 139.0616
# Warning: Safety violated! Slack: 122.6424
# Warning: Safety violated! Slack: 71.8230
# Warning: Safety violated! Slack: 140.9114
# Warning: Safety violated! Slack: 138.9405
# Warning: Safety violated! Slack: 122.5594
# Warning: Safety violated! Slack: 70.7990
# Warning: Safety violated! Slack: 140.8318
# Warning: Safety violated! Slack: 138.8171
# Warning: Safety violated! Slack: 122.4757
# Warning: Safety violated! Slack: 69.7575
# Warning: Safety violated! Slack: 140.7526
# Warning: Safety violated! Slack: 138.6915
# Warning: Safety violated! Slack: 122.3914
# Warning: Safety violated! Slack: 68.6986
# Warning: Safety violated! Slack: 140.6740
# Warning: Safety violated! Slack: 138.5636
# Warning: Safety violated! Slack: 122.3064
# Warning: Safety violated! Slack: 67.6222
# Warning: Safety violated! Slack: 140.5960
# Warning: Safety violated! Slack: 138.4338
# Warning: Safety violated! Slack: 122.2209
# Warning: Safety violated! Slack: 66.5284
# Warning: Safety violated! Slack: 140.5186
# Warning: Safety violated! Slack: 138.3019
# Warning: Safety violated! Slack: 122.1349
# Warning: Safety violated! Slack: 65.4171
# Warning: Safety violated! Slack: 140.4420
# Warning: Safety violated! Slack: 138.1681
# Warning: Safety violated! Slack: 122.0484
# Warning: Safety violated! Slack: 64.2884
# Warning: Safety violated! Slack: 140.3662
# Warning: Safety violated! Slack: 138.0325
# Warning: Safety violated! Slack: 121.9616
# Warning: Safety violated! Slack: 63.1422
# Warning: Safety violated! Slack: 140.2912
# Warning: Safety violated! Slack: 137.8952
# Warning: Safety violated! Slack: 121.8743
# Warning: Safety violated! Slack: 61.9785
# Warning: Safety violated! Slack: 140.2170
# Warning: Safety violated! Slack: 137.7562
# Warning: Safety violated! Slack: 121.7868
# Warning: Safety violated! Slack: 60.7973
# Warning: Safety violated! Slack: 140.1438
# Warning: Safety violated! Slack: 137.6156
# Warning: Safety violated! Slack: 121.6990
# Warning: Safety violated! Slack: 59.5986
# Warning: Safety violated! Slack: 140.0715
# Warning: Safety violated! Slack: 137.4735
# Warning: Safety violated! Slack: 121.6110
# Warning: Safety violated! Slack: 58.3824
# Warning: Safety violated! Slack: 140.0001
# Warning: Safety violated! Slack: 137.3300
# Warning: Safety violated! Slack: 121.5228
# Warning: Safety violated! Slack: 57.1486
# Warning: Safety violated! Slack: 139.9299
# Warning: Safety violated! Slack: 137.1852
# Warning: Safety violated! Slack: 121.4346
# Warning: Safety violated! Slack: 55.8973
# Warning: Safety violated! Slack: 139.8607
# Warning: Safety violated! Slack: 137.0391
# Warning: Safety violated! Slack: 121.3462
# Warning: Safety violated! Slack: 54.6284
# Warning: Safety violated! Slack: 139.7926
# Warning: Safety violated! Slack: 136.8918
# Warning: Safety violated! Slack: 121.2579
# Warning: Safety violated! Slack: 53.3418
# Warning: Safety violated! Slack: 139.7256
# Warning: Safety violated! Slack: 136.7433
# Warning: Safety violated! Slack: 121.1695
# Warning: Safety violated! Slack: 52.0376
# Warning: Safety violated! Slack: 139.6598
# Warning: Safety violated! Slack: 136.5938
# Warning: Safety violated! Slack: 121.0813
# Warning: Safety violated! Slack: 50.7157
# Warning: Safety violated! Slack: 139.5953
# Warning: Safety violated! Slack: 136.4433
# Warning: Safety violated! Slack: 120.9932
# Warning: Safety violated! Slack: 49.3761
# Warning: Safety violated! Slack: 139.5319
# Warning: Safety violated! Slack: 136.2918
# Warning: Safety violated! Slack: 120.9052
# Warning: Safety violated! Slack: 48.0187
# Warning: Safety violated! Slack: 139.4699
# Warning: Safety violated! Slack: 136.1395
# Warning: Safety violated! Slack: 120.8175
# Warning: Safety violated! Slack: 46.6435
# Warning: Safety violated! Slack: 139.4091
# Warning: Safety violated! Slack: 135.9864
# Warning: Safety violated! Slack: 120.7301
# Warning: Safety violated! Slack: 45.2505
# Warning: Safety violated! Slack: 139.3497
# Warning: Safety violated! Slack: 135.8326
# Warning: Safety violated! Slack: 120.6430
# Warning: Safety violated! Slack: 43.8396
# Warning: Safety violated! Slack: 139.2916
# Warning: Safety violated! Slack: 135.6780
# Warning: Safety violated! Slack: 120.5563
# Warning: Safety violated! Slack: 42.4107
# Warning: Safety violated! Slack: 139.2349
# Warning: Safety violated! Slack: 135.5229
# Warning: Safety violated! Slack: 120.4701
# Warning: Safety violated! Slack: 40.9638
# Warning: Safety violated! Slack: 139.1795
# Warning: Safety violated! Slack: 135.3673
# Warning: Safety violated! Slack: 120.3843
# Warning: Safety violated! Slack: 39.4989
# Warning: Safety violated! Slack: 139.1256
# Warning: Safety violated! Slack: 135.2111
# Warning: Safety violated! Slack: 120.2991
# Warning: Safety violated! Slack: 38.0158
# Warning: Safety violated! Slack: 139.0732
# Warning: Safety violated! Slack: 135.0545
# Warning: Safety violated! Slack: 120.2146
# Warning: Safety violated! Slack: 36.5146
# Warning: Safety violated! Slack: 139.0222
# Warning: Safety violated! Slack: 134.8976
# Warning: Safety violated! Slack: 120.1307
# Warning: Safety violated! Slack: 34.9944
# Warning: Safety violated! Slack: 138.9727
# Warning: Safety violated! Slack: 134.7403
# Warning: Safety violated! Slack: 120.0475
# Warning: Safety violated! Slack: 33.4543
# Warning: Safety violated! Slack: 138.9247
# Warning: Safety violated! Slack: 134.5828
# Warning: Safety violated! Slack: 119.9650
# Warning: Safety violated! Slack: 31.8944
# Warning: Safety violated! Slack: 138.8783
# Warning: Safety violated! Slack: 134.4251
# Warning: Safety violated! Slack: 119.8833
# Warning: Safety violated! Slack: 30.3146
# Warning: Safety violated! Slack: 138.8334
# Warning: Safety violated! Slack: 134.2673
# Warning: Safety violated! Slack: 119.8026
# Warning: Safety violated! Slack: 28.7148
# Warning: Safety violated! Slack: 138.7900
# Warning: Safety violated! Slack: 134.1094
# Warning: Safety violated! Slack: 119.7228
# Warning: Safety violated! Slack: 27.0949
# Warning: Safety violated! Slack: 138.7483
# Warning: Safety violated! Slack: 133.9515
# Warning: Safety violated! Slack: 119.6440
# Warning: Safety violated! Slack: 25.4548
# Warning: Safety violated! Slack: 138.7081
# Warning: Safety violated! Slack: 133.7936
# Warning: Safety violated! Slack: 119.5663
# Warning: Safety violated! Slack: 23.7945
# Warning: Safety violated! Slack: 138.6695
# Warning: Safety violated! Slack: 133.6357
# Warning: Safety violated! Slack: 119.4899
# Warning: Safety violated! Slack: 22.1138
# Warning: Safety violated! Slack: 138.6326
# Warning: Safety violated! Slack: 133.4781
# Warning: Safety violated! Slack: 119.4147
# Warning: Safety violated! Slack: 20.4128
# Warning: Safety violated! Slack: 138.5974
# Warning: Safety violated! Slack: 133.3206
# Warning: Safety violated! Slack: 119.3409
# Warning: Safety violated! Slack: 18.6913
# Warning: Safety violated! Slack: 138.5638
# Warning: Safety violated! Slack: 133.1634
# Warning: Safety violated! Slack: 119.2686
# Warning: Safety violated! Slack: 16.9493
# Warning: Safety violated! Slack: 138.5319
# Warning: Safety violated! Slack: 133.0065
# Warning: Safety violated! Slack: 119.1978
# Warning: Safety violated! Slack: 15.1866
# Warning: Safety violated! Slack: 138.5017
# Warning: Safety violated! Slack: 132.8500
# Warning: Safety violated! Slack: 119.1287
# Warning: Safety violated! Slack: 13.4032
# Warning: Safety violated! Slack: 138.4732
# Warning: Safety violated! Slack: 132.6939
# Warning: Safety violated! Slack: 119.0614
# Warning: Safety violated! Slack: 11.5989
# Warning: Safety violated! Slack: 138.4465
# Warning: Safety violated! Slack: 132.5382
# Warning: Safety violated! Slack: 118.9959
# Warning: Safety violated! Slack: 9.7738
# Warning: Safety violated! Slack: 138.4215
# Warning: Safety violated! Slack: 132.3831
# Warning: Safety violated! Slack: 118.9325
# Warning: Safety violated! Slack: 7.9277
# Warning: Safety violated! Slack: 138.3983
# Warning: Safety violated! Slack: 132.2286
# Warning: Safety violated! Slack: 118.8711
# Warning: Safety violated! Slack: 6.0605
# Warning: Safety violated! Slack: 138.3769
# Warning: Safety violated! Slack: 132.0748
# Warning: Safety violated! Slack: 118.8119
# Warning: Safety violated! Slack: 4.1721
# Warning: Safety violated! Slack: 138.3573
# Warning: Safety violated! Slack: 131.9216
# Warning: Safety violated! Slack: 118.7551
# Warning: Safety violated! Slack: 2.2624
# Warning: Safety violated! Slack: 138.3395
# Warning: Safety violated! Slack: 131.7693
# Warning: Safety violated! Slack: 118.7007
# Warning: Safety violated! Slack: 0.3315
# Warning: Safety violated! Slack: 138.3236
# Warning: Safety violated! Slack: 131.6177
# Warning: Safety violated! Slack: 118.6490
# Warning: Safety violated! Slack: 138.3096
# Warning: Safety violated! Slack: 131.4671
# Warning: Safety violated! Slack: 118.6000
# Warning: Safety violated! Slack: 138.2975
# Warning: Safety violated! Slack: 131.3173
# Warning: Safety violated! Slack: 118.5539
# Warning: Safety violated! Slack: 138.2873
# Warning: Safety violated! Slack: 131.1686
# Warning: Safety violated! Slack: 118.5108
# Warning: Safety violated! Slack: 138.2790
# Warning: Safety violated! Slack: 131.0210
# Warning: Safety violated! Slack: 118.4710
# Warning: Safety violated! Slack: 138.2727
# Warning: Safety violated! Slack: 130.8745
# Warning: Safety violated! Slack: 118.4346
# Warning: Safety violated! Slack: 138.2684
# Warning: Safety violated! Slack: 130.7293
# Warning: Safety violated! Slack: 118.4017
# Warning: Safety violated! Slack: 138.2662
# Warning: Safety violated! Slack: 130.5853
# Warning: Safety violated! Slack: 118.3727
# Warning: Safety violated! Slack: 138.2660
# Warning: Safety violated! Slack: 130.4426
# Warning: Safety violated! Slack: 118.3476
# Warning: Safety violated! Slack: 138.2679
# Warning: Safety violated! Slack: 130.3014
# Warning: Safety violated! Slack: 118.3267
# Warning: Safety violated! Slack: 138.2719
# Warning: Safety violated! Slack: 130.1617
# Warning: Safety violated! Slack: 118.3103
# Warning: Safety violated! Slack: 138.2782
# Warning: Safety violated! Slack: 130.0235
# Warning: Safety violated! Slack: 118.2985
# Warning: Safety violated! Slack: 138.2866
# Warning: Safety violated! Slack: 129.8870
# Warning: Safety violated! Slack: 118.2916
# Warning: Safety violated! Slack: 138.2974
# Warning: Safety violated! Slack: 129.7523
# Warning: Safety violated! Slack: 118.2900
# Warning: Safety violated! Slack: 138.3104
# Warning: Safety violated! Slack: 129.6193
# Warning: Safety violated! Slack: 118.2938
# Warning: Safety violated! Slack: 138.3259
# Warning: Safety violated! Slack: 129.4883
# Warning: Safety violated! Slack: 118.3035
# Warning: Safety violated! Slack: 138.3437
# Warning: Safety violated! Slack: 129.3592
# Warning: Safety violated! Slack: 118.3193
# Warning: Safety violated! Slack: 138.3641
# Warning: Safety violated! Slack: 129.2323
# Warning: Safety violated! Slack: 118.3417
# Warning: Safety violated! Slack: 138.3869
# Warning: Safety violated! Slack: 129.1075
# Warning: Safety violated! Slack: 118.3710
# Warning: Safety violated! Slack: 138.4125
# Warning: Safety violated! Slack: 128.9850
# Warning: Safety violated! Slack: 118.4076
# Warning: Safety violated! Slack: 138.4407
# Warning: Safety violated! Slack: 128.8649
# Warning: Safety violated! Slack: 118.4520
# Warning: Safety violated! Slack: 138.4716
# Warning: Safety violated! Slack: 128.7473
# Warning: Safety violated! Slack: 118.5047
# Warning: Safety violated! Slack: 138.5055
# Warning: Safety violated! Slack: 128.6324
# Warning: Safety violated! Slack: 118.5951
# Warning: Safety violated! Slack: 138.5422
# Warning: Safety violated! Slack: 128.5202
# Warning: Safety violated! Slack: 118.8187
# Warning: Safety violated! Slack: 138.5820
# Warning: Safety violated! Slack: 128.4108
# Warning: Safety violated! Slack: 119.0545
# Warning: Safety violated! Slack: 138.6249
# Warning: Safety violated! Slack: 128.3045
# Warning: Safety violated! Slack: 119.3035
# Warning: Safety violated! Slack: 138.6710
# Warning: Safety violated! Slack: 128.2012
# Warning: Safety violated! Slack: 119.5668
# Warning: Safety violated! Slack: 138.7205
# Warning: Safety violated! Slack: 128.1013
# Warning: Safety violated! Slack: 119.8454
# Warning: Safety violated! Slack: 138.7734
# Warning: Safety violated! Slack: 128.0048
# Warning: Safety violated! Slack: 120.1408
# Warning: Safety violated! Slack: 138.8298
# Warning: Safety violated! Slack: 127.9120
# Warning: Safety violated! Slack: 120.4542
# Warning: Safety violated! Slack: 138.8900
# Warning: Safety violated! Slack: 127.8229
# Warning: Safety violated! Slack: 120.7873
# Warning: Safety violated! Slack: 138.9540
# Warning: Safety violated! Slack: 127.7377
# Warning: Safety violated! Slack: 121.1418
# Warning: Safety violated! Slack: 139.0219
# Warning: Safety violated! Slack: 127.6567
# Warning: Safety violated! Slack: 121.5198
# Warning: Safety violated! Slack: 139.0940
# Warning: Safety violated! Slack: 127.5800
# Warning: Safety violated! Slack: 121.9236
# Warning: Safety violated! Slack: 139.1704
# Warning: Safety violated! Slack: 127.5079
# Warning: Safety violated! Slack: 122.3558
# Warning: Safety violated! Slack: 139.2512
# Warning: Safety violated! Slack: 127.4405
# Warning: Safety violated! Slack: 122.8195
# Warning: Safety violated! Slack: 139.3367
# Warning: Safety violated! Slack: 127.3780
# Warning: Safety violated! Slack: 123.3181
# Warning: Safety violated! Slack: 139.4270
# Warning: Safety violated! Slack: 127.3208
# Warning: Safety violated! Slack: 123.8557
# Warning: Safety violated! Slack: 139.5223
# Warning: Safety violated! Slack: 127.2689
# Warning: Safety violated! Slack: 124.4371
# Warning: Safety violated! Slack: 139.6229
# Warning: Safety violated! Slack: 127.2228
# Warning: Safety violated! Slack: 125.0677
# Warning: Safety violated! Slack: 139.7289
# Warning: Safety violated! Slack: 127.1826
# Warning: Safety violated! Slack: 125.7542
# Warning: Safety violated! Slack: 139.8406
# Warning: Safety violated! Slack: 127.1487
# Warning: Safety violated! Slack: 126.5045
# Warning: Safety violated! Slack: 139.9583
# Warning: Safety violated! Slack: 127.1213
# Warning: Safety violated! Slack: 127.3281
# Warning: Safety violated! Slack: 140.0822
# Warning: Safety violated! Slack: 127.1007
# Warning: Safety violated! Slack: 128.2366
# Warning: Safety violated! Slack: 140.2126
# Warning: Safety violated! Slack: 127.0873
# Warning: Safety violated! Slack: 129.2446
# Warning: Safety violated! Slack: 140.3499
# Warning: Safety violated! Slack: 127.0815
# Warning: Safety violated! Slack: 130.3701
# Warning: Safety violated! Slack: 140.4942
# Warning: Safety violated! Slack: 127.0835
# Warning: Safety violated! Slack: 131.6363
# Warning: Safety violated! Slack: 140.6460
# Warning: Safety violated! Slack: 127.0937
# Warning: Safety violated! Slack: 133.0736
# Warning: Safety violated! Slack: 140.8056
# Warning: Safety violated! Slack: 127.1126
# Warning: Safety violated! Slack: 134.7222
# Warning: Safety violated! Slack: 140.9734
# Warning: Safety violated! Slack: 127.1406
# Warning: Safety violated! Slack: 136.6373
# Warning: Safety violated! Slack: 141.1498
# Warning: Safety violated! Slack: 127.1781
# Warning: Safety violated! Slack: 138.8971
# Warning: Safety violated! Slack: 141.3353
# Warning: Safety violated! Slack: 127.2256
# Warning: Safety violated! Slack: 141.6162
# Warning: Safety violated! Slack: 141.5302
# Warning: Safety violated! Slack: 127.2835
# Warning: Safety violated! Slack: 144.9722
# Warning: Safety violated! Slack: 141.7350
# Warning: Safety violated! Slack: 127.3524
# Warning: Safety violated! Slack: 149.2573
# Warning: Safety violated! Slack: 5.3065
# Warning: Safety violated! Slack: 141.9504
# Warning: Safety violated! Slack: 127.4328
# Warning: Safety violated! Slack: 154.9970
# Warning: Safety violated! Slack: 14.6477
# Warning: Safety violated! Slack: 142.1767
# Warning: Safety violated! Slack: 127.5253
# Warning: Safety violated! Slack: 163.6116
# Warning: Safety violated! Slack: 30.3634
# Warning: Safety violated! Slack: 142.4147
# Warning: Safety violated! Slack: 127.6304
# Warning: Safety violated! Slack: 178.4620
# Warning: Safety violated! Slack: 65.4751
# Warning: Safety violated! Slack: 142.6649
# Warning: Safety violated! Slack: 127.7487
# Warning: Safety violated! Slack: 212.3034
# Warning: Safety violated! Slack: 547.7588
# Warning: Safety violated! Slack: 142.9279
# Warning: Safety violated! Slack: 127.8807
# Warning: Safety violated! Slack: 571.2475
# Warning: Safety violated! Slack: 73435925.2166
# Warning: Safety violated! Slack: 143.2045
# Warning: Safety violated! Slack: 128.0267
# Warning: Safety violated! Slack: 73435925.2166
# Warning: Safety violated! Slack: 22562058.0630
# Warning: Safety violated! Slack: 143.4955
# Warning: Safety violated! Slack: 128.1814
# Warning: Safety violated! Slack: 22562058.0630
# Warning: Safety violated! Slack: 143.8017
# Warning: Safety violated! Slack: 128.3450
# Warning: Safety violated! Slack: 144.1238
# Warning: Safety violated! Slack: 128.5183
# Warning: Safety violated! Slack: 144.4628
# Warning: Safety violated! Slack: 128.7148
# Warning: Safety violated! Slack: 2828187.9545
# Warning: Safety violated! Slack: 144.8197
# Warning: Safety violated! Slack: 128.9357
# Warning: Safety violated! Slack: 2828187.9545
# Warning: Safety violated! Slack: 145.1955
# Warning: Safety violated! Slack: 129.1822
# Warning: Safety violated! Slack: 145.5916
# Warning: Safety violated! Slack: 129.4431
# Warning: Safety violated! Slack: 146.0090
# Warning: Safety violated! Slack: 129.7322
# Warning: Safety violated! Slack: 146.4491
# Warning: Safety violated! Slack: 130.0512
# Warning: Safety violated! Slack: 37.0369
# Warning: Safety violated! Slack: 146.9134
# Warning: Safety violated! Slack: 130.4017
# Warning: Safety violated! Slack: 52.2843
# Warning: Safety violated! Slack: 147.4035
# Warning: Safety violated! Slack: 130.7840
# Warning: Safety violated! Slack: 59.5306
# ...
# Warning: Safety violated! Slack: 25363542.0894
# Warning: Safety violated! Slack: 25363542.0894
# Warning: Safety violated! Slack: 19.7035
# Warning: Safety violated! Slack: 1.2679
# Warning: Safety violated! Slack: 22.6343
# Warning: Safety violated! Slack: 24.4109
# Warning: Safety violated! Slack: 51.2123
# Warning: Safety violated! Slack: 96.6813
# Warning: Safety violated! Slack: 507245.4750
# Warning: Safety violated! Slack: 507245.4750
# Warning: Safety violated! Slack: 26.8676
# Warning: Safety violated! Slack: 44.5601
# Warning: Safety violated! Slack: 9682188.8182
# Warning: Safety violated! Slack: 9682188.8182
# Warning: Safety violated! Slack: 11.8211
# Warning: Safety violated! Slack: 0.1258
# Warning: Safety violated! Slack: 0.2398
# Warning: Safety violated! Slack: 0.3510
# Warning: Safety violated! Slack: 0.4596
# Warning: Safety violated! Slack: 0.5654
# Warning: Safety violated! Slack: 0.6687
# Warning: Safety violated! Slack: 0.7694
# Warning: Safety violated! Slack: 0.8675
# Warning: Safety violated! Slack: 0.9632
# Warning: Safety violated! Slack: 1.0565
# Warning: Safety violated! Slack: 1.1473
# Warning: Safety violated! Slack: 1.2358
# Warning: Safety violated! Slack: 1.3220
# Warning: Safety violated! Slack: 1.4059
# Warning: Safety violated! Slack: 1.4876
# Warning: Safety violated! Slack: 1.5670
# Warning: Safety violated! Slack: 1.6443
# Warning: Safety violated! Slack: 1.7195
# Warning: Safety violated! Slack: 1.7926
# Warning: Safety violated! Slack: 1.8636
# Warning: Safety violated! Slack: 1.9326
# Warning: Safety violated! Slack: 1.9997
# Warning: Safety violated! Slack: 2.0647
# Warning: Safety violated! Slack: 2.1279
# Warning: Safety violated! Slack: 2.1891
# Warning: Safety violated! Slack: 2.2485
# Warning: Safety violated! Slack: 2.3061
# Warning: Safety violated! Slack: 2.3619
# Warning: Safety violated! Slack: 2.4159
# Warning: Safety violated! Slack: 2.4682
# Warning: Safety violated! Slack: 2.5188
# Warning: Safety violated! Slack: 2.5677
# Warning: Safety violated! Slack: 2.6149
# Warning: Safety violated! Slack: 2.6605
# Warning: Safety violated! Slack: 2.7046
# Warning: Safety violated! Slack: 2.7471
# Warning: Safety violated! Slack: 2.7880
# Warning: Safety violated! Slack: 2.8274
# Warning: Safety violated! Slack: 2.8654
# Warning: Safety violated! Slack: 2.9018
# Warning: Safety violated! Slack: 2.9369
# Warning: Safety violated! Slack: 2.9705
# Warning: Safety violated! Slack: 3.0027
# Warning: Safety violated! Slack: 3.0336
# Warning: Safety violated! Slack: 3.0632
# Warning: Safety violated! Slack: 3.0914
# Warning: Safety violated! Slack: 3.1183
# Warning: Safety violated! Slack: 3.1440
# Warning: Safety violated! Slack: 3.1684
# Warning: Safety violated! Slack: 3.1916
# Warning: Safety violated! Slack: 3.2136
# Warning: Safety violated! Slack: 3.2344
# Warning: Safety violated! Slack: 3.2540
# Warning: Safety violated! Slack: 3.2725
# Warning: Safety violated! Slack: 3.2899
# Warning: Safety violated! Slack: 3.3062
# Warning: Safety violated! Slack: 3.3214
# Warning: Safety violated! Slack: 3.3355
# Warning: Safety violated! Slack: 3.3486
# Warning: Safety violated! Slack: 3.3607
# Warning: Safety violated! Slack: 3.3718
# Warning: Safety violated! Slack: 3.3818
# Warning: Safety violated! Slack: 3.3910
# Warning: Safety violated! Slack: 3.3992
# Warning: Safety violated! Slack: 3.4064
# Warning: Safety violated! Slack: 3.4128
# Warning: Safety violated! Slack: 3.4182
# Warning: Safety violated! Slack: 3.4228
# Warning: Safety violated! Slack: 3.4265
# Warning: Safety violated! Slack: 3.4294
# Warning: Safety violated! Slack: 3.4314
# Warning: Safety violated! Slack: 3.4327
# Warning: Safety violated! Slack: 3.4331
# Warning: Safety violated! Slack: 3.4328
# Warning: Safety violated! Slack: 3.4317
# Warning: Safety violated! Slack: 3.4298
# Warning: Safety violated! Slack: 3.4273
# Warning: Safety violated! Slack: 3.4240
# Warning: Safety violated! Slack: 3.4200
# Warning: Safety violated! Slack: 3.4153
# Warning: Safety violated! Slack: 3.4100
# Warning: Safety violated! Slack: 3.4040
# Warning: Safety violated! Slack: 3.3973
# Warning: Safety violated! Slack: 3.3901
# Warning: Safety violated! Slack: 3.3822
# Warning: Safety violated! Slack: 3.3737
# Warning: Safety violated! Slack: 3.3646
# Warning: Safety violated! Slack: 3.3550
# Warning: Safety violated! Slack: 3.3447
# Warning: Safety violated! Slack: 3.3340
# Warning: Safety violated! Slack: 3.3227
# Warning: Safety violated! Slack: 3.3109
# Warning: Safety violated! Slack: 3.2986
# Warning: Safety violated! Slack: 3.2857
# Warning: Safety violated! Slack: 3.2724
# Warning: Safety violated! Slack: 3.2586
# Warning: Safety violated! Slack: 3.2444
# Warning: Safety violated! Slack: 3.2297
# Warning: Safety violated! Slack: 3.2145
# Warning: Safety violated! Slack: 3.1990
# Warning: Safety violated! Slack: 3.1830
# Warning: Safety violated! Slack: 3.1666
# Warning: Safety violated! Slack: 3.1498
# Warning: Safety violated! Slack: 3.1326
# Warning: Safety violated! Slack: 3.1151
# Warning: Safety violated! Slack: 3.0972
# Warning: Safety violated! Slack: 3.0789
# Warning: Safety violated! Slack: 3.0603
# Warning: Safety violated! Slack: 3.0414
# Warning: Safety violated! Slack: 3.0221
# Warning: Safety violated! Slack: 3.0025
# Warning: Safety violated! Slack: 2.9827
# Warning: Safety violated! Slack: 2.9625
# Warning: Safety violated! Slack: 2.9420
# Warning: Safety violated! Slack: 2.9213
# Warning: Safety violated! Slack: 2.9003
# Warning: Safety violated! Slack: 2.8790
# Warning: Safety violated! Slack: 2.8575
# Warning: Safety violated! Slack: 2.8358
# Warning: Safety violated! Slack: 2.8138
# Warning: Safety violated! Slack: 2.7916
# Warning: Safety violated! Slack: 2.7692
# Warning: Safety violated! Slack: 2.7465
# Warning: Safety violated! Slack: 2.7237
# Warning: Safety violated! Slack: 2.7007
# Warning: Safety violated! Slack: 2.6775
# Warning: Safety violated! Slack: 2.6541
# Warning: Safety violated! Slack: 2.6305
# Warning: Safety violated! Slack: 2.6068
# Warning: Safety violated! Slack: 2.5830
# Warning: Safety violated! Slack: 2.5590
# Warning: Safety violated! Slack: 2.5348
# Warning: Safety violated! Slack: 2.5106
# Warning: Safety violated! Slack: 2.4862
# Warning: Safety violated! Slack: 2.4616
# Warning: Safety violated! Slack: 2.4370
# Warning: Safety violated! Slack: 2.4123
# Warning: Safety violated! Slack: 2.3874
# Warning: Safety violated! Slack: 2.3625
# Warning: Safety violated! Slack: 2.3375
# Warning: Safety violated! Slack: 2.3124
# Warning: Safety violated! Slack: 2.2873
# Warning: Safety violated! Slack: 2.2620
# Warning: Safety violated! Slack: 2.2368
# Warning: Safety violated! Slack: 2.2114
# Warning: Safety violated! Slack: 2.1860
# Warning: Safety violated! Slack: 2.1606
# Warning: Safety violated! Slack: 2.1351
# Warning: Safety violated! Slack: 2.1096
# Warning: Safety violated! Slack: 2.0841
# Warning: Safety violated! Slack: 2.0585
# Warning: Safety violated! Slack: 2.0330
# Warning: Safety violated! Slack: 2.0074
# Warning: Safety violated! Slack: 1.9818
# Warning: Safety violated! Slack: 1.9562
# Warning: Safety violated! Slack: 1.9306
# Warning: Safety violated! Slack: 1.9051
# Warning: Safety violated! Slack: 1.8796
# Warning: Safety violated! Slack: 1.8541
# Warning: Safety violated! Slack: 1.8287
# Warning: Safety violated! Slack: 1.8034
# Warning: Safety violated! Slack: 1.7782
# Warning: Safety violated! Slack: 1.7530
# Warning: Safety violated! Slack: 1.7280
# Warning: Safety violated! Slack: 1.7030
# Warning: Safety violated! Slack: 1.6782
# Warning: Safety violated! Slack: 1.6535
# Warning: Safety violated! Slack: 1.6290
# Warning: Safety violated! Slack: 1.6046
# Warning: Safety violated! Slack: 1.5804
# Warning: Safety violated! Slack: 1.5563
# Warning: Safety violated! Slack: 1.5325
# Warning: Safety violated! Slack: 1.5088
# Warning: Safety violated! Slack: 1.4853
# Warning: Safety violated! Slack: 1.4620
# Warning: Safety violated! Slack: 1.4390
# Warning: Safety violated! Slack: 1.4161
# Warning: Safety violated! Slack: 1.3936
# Warning: Safety violated! Slack: 1.3712
# Warning: Safety violated! Slack: 1.3491
# Warning: Safety violated! Slack: 1.3273
# Warning: Safety violated! Slack: 1.3057
# Warning: Safety violated! Slack: 1.2844
# Warning: Safety violated! Slack: 1.2872
# Warning: Safety violated! Slack: 1.4322
# Warning: Safety violated! Slack: 1.5748
# Warning: Safety violated! Slack: 1.7151
# Warning: Safety violated! Slack: 1.8530
# Warning: Safety violated! Slack: 1.9887
# Warning: Safety violated! Slack: 2.1220
# Warning: Safety violated! Slack: 2.2530
# Warning: Safety violated! Slack: 2.3817
# Warning: Safety violated! Slack: 2.5080
# Warning: Safety violated! Slack: 2.6320
# Warning: Safety violated! Slack: 2.7536
# Warning: Safety violated! Slack: 2.8729
# Warning: Safety violated! Slack: 2.9899
# Warning: Safety violated! Slack: 3.1045
# Warning: Safety violated! Slack: 3.2167
# Warning: Safety violated! Slack: 3.3267
# Warning: Safety violated! Slack: 3.4342
# Warning: Safety violated! Slack: 3.5394
# Warning: Safety violated! Slack: 3.6423
# Warning: Safety violated! Slack: 3.7428
# Warning: Safety violated! Slack: 3.8409
# Warning: Safety violated! Slack: 3.9367
# Warning: Safety violated! Slack: 4.0302
# Warning: Safety violated! Slack: 4.1213
# Warning: Safety violated! Slack: 4.2100
# Warning: Safety violated! Slack: 4.2964
# Warning: Safety violated! Slack: 4.3804
# Warning: Safety violated! Slack: 4.4621
# Warning: Safety violated! Slack: 4.5415
# Warning: Safety violated! Slack: 4.6190
# Warning: Safety violated! Slack: 4.6951
# Warning: Safety violated! Slack: 4.7698
# Warning: Safety violated! Slack: 4.8430
# Warning: Safety violated! Slack: 4.9147
# Warning: Safety violated! Slack: 4.9850
# Warning: Safety violated! Slack: 5.0540
# Warning: Safety violated! Slack: 5.1215
# Warning: Safety violated! Slack: 5.1877
# Warning: Safety violated! Slack: 5.2525
# Warning: Safety violated! Slack: 5.3159
# Warning: Safety violated! Slack: 5.3780
# Warning: Safety violated! Slack: 5.4388
# Warning: Safety violated! Slack: 5.4982
# Warning: Safety violated! Slack: 5.5563
# Warning: Safety violated! Slack: 5.6131
# Warning: Safety violated! Slack: 5.6687
# Warning: Safety violated! Slack: 5.7229
# Warning: Safety violated! Slack: 5.7759
# Warning: Safety violated! Slack: 5.8276
# Warning: Safety violated! Slack: 5.8781
# Warning: Safety violated! Slack: 5.9274
# Warning: Safety violated! Slack: 5.9754
# Warning: Safety violated! Slack: 6.0221
# Warning: Safety violated! Slack: 6.0677
# Warning: Safety violated! Slack: 6.1121
# Warning: Safety violated! Slack: 6.1553
# Warning: Safety violated! Slack: 6.1973
# Warning: Safety violated! Slack: 6.2381
# Warning: Safety violated! Slack: 6.2777
# Warning: Safety violated! Slack: 6.3162
# Warning: Safety violated! Slack: 6.3535
# Warning: Safety violated! Slack: 6.3897
# Warning: Safety violated! Slack: 6.4248
# Warning: Safety violated! Slack: 6.4587
# Warning: Safety violated! Slack: 6.4915
# Warning: Safety violated! Slack: 6.5232
# Warning: Safety violated! Slack: 6.5538
# Warning: Safety violated! Slack: 6.5833
# Warning: Safety violated! Slack: 6.6117
# Warning: Safety violated! Slack: 6.6390
# Warning: Safety violated! Slack: 6.6653
# Warning: Safety violated! Slack: 6.6905
# Warning: Safety violated! Slack: 6.7146
# Warning: Safety violated! Slack: 6.7377
# Warning: Safety violated! Slack: 6.7597
# Warning: Safety violated! Slack: 6.7808
# Warning: Safety violated! Slack: 6.8007
# Warning: Safety violated! Slack: 6.8197
# Warning: Safety violated! Slack: 6.8376
# Warning: Safety violated! Slack: 6.8546
# Warning: Safety violated! Slack: 6.8705
# Warning: Safety violated! Slack: 6.8855
# Warning: Safety violated! Slack: 6.8994
# Warning: Safety violated! Slack: 6.9124
# Warning: Safety violated! Slack: 6.9244
# Warning: Safety violated! Slack: 6.9354
# Warning: Safety violated! Slack: 6.9455
# Warning: Safety violated! Slack: 6.9547
# Warning: Safety violated! Slack: 6.9629
# Warning: Safety violated! Slack: 6.9701
# Warning: Safety violated! Slack: 6.9764
# Warning: Safety violated! Slack: 6.9818
# Warning: Safety violated! Slack: 6.9863
# Warning: Safety violated! Slack: 6.9899
# Warning: Safety violated! Slack: 6.9925
# Warning: Safety violated! Slack: 6.9943
# Warning: Safety violated! Slack: 6.9952
# Warning: Safety violated! Slack: 6.9952
# Warning: Safety violated! Slack: 6.9943
# Warning: Safety violated! Slack: 6.9926
# Warning: Safety violated! Slack: 6.9900
# Warning: Safety violated! Slack: 6.9865
# Warning: Safety violated! Slack: 6.9822
# Warning: Safety violated! Slack: 6.9770
# Warning: Safety violated! Slack: 6.9710
# Warning: Safety violated! Slack: 6.9642
# Warning: Safety violated! Slack: 6.9544
# Warning: Safety violated! Slack: 6.9387
# Warning: Safety violated! Slack: 6.9224
# Warning: Safety violated! Slack: 6.9053
# Warning: Safety violated! Slack: 6.8876
# Warning: Safety violated! Slack: 6.8693
# Warning: Safety violated! Slack: 6.8502
# Warning: Safety violated! Slack: 6.8305
# Warning: Safety violated! Slack: 6.8102
# Warning: Safety violated! Slack: 6.7892
# Warning: Safety violated! Slack: 6.7676
# Warning: Safety violated! Slack: 6.7453
# Warning: Safety violated! Slack: 6.7224
# Warning: Safety violated! Slack: 6.6989
# Warning: Safety violated! Slack: 6.6747
# Warning: Safety violated! Slack: 6.6499
# Warning: Safety violated! Slack: 6.6245
# Warning: Safety violated! Slack: 6.5985
# Warning: Safety violated! Slack: 6.5719
# Warning: Safety violated! Slack: 6.5447
# Warning: Safety violated! Slack: 6.5168
# Warning: Safety violated! Slack: 6.4884
# Warning: Safety violated! Slack: 6.4594
# Warning: Safety violated! Slack: 6.4298
# Warning: Safety violated! Slack: 6.3997
# Warning: Safety violated! Slack: 6.3689
# Warning: Safety violated! Slack: 6.3376
# Warning: Safety violated! Slack: 6.3057
# Warning: Safety violated! Slack: 6.2733
# Warning: Safety violated! Slack: 6.2403
# Warning: Safety violated! Slack: 6.2067
# Warning: Safety violated! Slack: 6.1726
# Warning: Safety violated! Slack: 6.1379
# Warning: Safety violated! Slack: 6.1027
# Warning: Safety violated! Slack: 6.0670
# Warning: Safety violated! Slack: 6.0307
# Warning: Safety violated! Slack: 5.9940
# Warning: Safety violated! Slack: 5.9567
# Warning: Safety violated! Slack: 5.9188
# Warning: Safety violated! Slack: 5.8805
# Warning: Safety violated! Slack: 5.8417
# Warning: Safety violated! Slack: 5.8024
# Warning: Safety violated! Slack: 5.7625
# Warning: Safety violated! Slack: 5.7222
# Warning: Safety violated! Slack: 5.6815
# Warning: Safety violated! Slack: 5.6402
# Warning: Safety violated! Slack: 5.5985
# Warning: Safety violated! Slack: 5.5563
# Warning: Safety violated! Slack: 5.5137
# Warning: Safety violated! Slack: 5.4706
# Warning: Safety violated! Slack: 5.4249
# Warning: Safety violated! Slack: 5.3626
# Warning: Safety violated! Slack: 5.2840
# Warning: Safety violated! Slack: 5.1895
# Warning: Safety violated! Slack: 5.0793
# Warning: Safety violated! Slack: 4.9536
# Warning: Safety violated! Slack: 4.8127
# Warning: Safety violated! Slack: 4.6567
# Warning: Safety violated! Slack: 4.4859
# Warning: Safety violated! Slack: 4.3005
# Warning: Safety violated! Slack: 4.1006
# Warning: Safety violated! Slack: 3.8865
# Warning: Safety violated! Slack: 3.6582
# Warning: Safety violated! Slack: 3.4159
# Warning: Safety violated! Slack: 3.1597
# Warning: Safety violated! Slack: 2.9177
# Warning: Safety violated! Slack: 2.8226
# Warning: Safety violated! Slack: 2.7263
# Warning: Safety violated! Slack: 2.6289
# Warning: Safety violated! Slack: 2.5304
# Warning: Safety violated! Slack: 2.4310
# Warning: Safety violated! Slack: 2.3307
# Warning: Safety violated! Slack: 2.2296
# Warning: Safety violated! Slack: 2.1276
# Warning: Safety violated! Slack: 2.0249
# Warning: Safety violated! Slack: 1.9216
# Warning: Safety violated! Slack: 1.8176
# Warning: Safety violated! Slack: 1.7131
# Warning: Safety violated! Slack: 1.6080
# Warning: Safety violated! Slack: 1.5025
# Warning: Safety violated! Slack: 1.3966
# Warning: Safety violated! Slack: 1.2904
# Warning: Safety violated! Slack: 1.1840
# Warning: Safety violated! Slack: 1.0773
# Warning: Safety violated! Slack: 0.9704
# Warning: Safety violated! Slack: 0.8635
# Warning: Safety violated! Slack: 0.7565
# Warning: Safety violated! Slack: 0.6495
# Warning: Safety violated! Slack: 0.5426
# Warning: Safety violated! Slack: 0.4358
# Warning: Safety violated! Slack: 0.3292
# Warning: Safety violated! Slack: 0.2229
# Warning: Safety violated! Slack: 0.1168

# %%
# # --- Plot control inputs (for debugging) ---
# time = np.arange(len(u_nom_hist[0])) * dt

# fig, axes = plt.subplots(N, 2, figsize=(10, 3*N))

# for i in range(N):
#     u_nom = u_nom_hist[i]
#     u_safe = u_safe_hist[i]

#     # X control
#     axes[i,0].plot(time, u_nom[:,0], '--', label='u_nom_x')
#     axes[i,0].plot(time, u_safe[:,0], '-', label='u_safe_x')
#     axes[i,0].set_title(f'Agent {i} - X acceleration')
#     axes[i,0].set_xlabel('Time (s)')
#     axes[i,0].set_ylabel('Acceleration')
#     axes[i,0].grid(True)
#     axes[i,0].legend()

#     # Y control
#     axes[i,1].plot(time, u_nom[:,1], '--', label='u_nom_y')
#     axes[i,1].plot(time, u_safe[:,1], '-', label='u_safe_y')
#     axes[i,1].set_title(f'Agent {i} - Y acceleration')
#     axes[i,1].set_xlabel('Time (s)')
#     axes[i,1].set_ylabel('Acceleration')
#     axes[i,1].grid(True)
#     axes[i,1].legend()

# plt.tight_layout()
# plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from matplotlib.animation import FFMpegWriter, FuncAnimation

# --- Reinitialize agents ---
agents_list = []
history = [[] for _ in range(N)]

for i in range(N):
    angle = 2 * np.pi * i / N

    x0 = [
        R_circle * np.cos(angle),
        R_circle * np.sin(angle),
        0.0,
        0.0
    ]

    target = -np.array(x0[0:2]) - 10

    # agent_id must be 1-based for your DecentralizedCBF
    ag = Agent(i + 1, x0, [0, 0, 0, 0], alpha=alpha_val, beta=beta_val)
    ag.target = target
    agents_list.append(ag)

# --- Dynamics topology ---
topology = CBFTopology(agents_list, d_min, gamma)
topology._compute_neighborhood_radii()

# --- Decentralized CBF filter ---
cbf_filter = DecentralizedCBF(gamma=gamma, safety_dis=d_min)

# --- Animation figure ---
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlim(-R_circle - 50, R_circle + 50)
ax.set_ylim(-R_circle - 50, R_circle + 50)
ax.set_aspect("equal")
ax.grid(True)
ax.set_title(f"{N} Robot Swapping - Decentralized CBF (gamma={gamma}, d_min={d_min})")

# plot targets
for ag in agents_list:
    ax.scatter(ag.target[0], ag.target[1], marker="x", color="red", s=100)

points = [ax.plot([], [], "o", ms=10)[0] for _ in range(N)]
trails = [ax.plot([], [], alpha=0.3, lw=1.5)[0] for _ in range(N)]

# safety circles
circles = []
for ag in agents_list:
    c = plt.Circle(
        (ag.pos[0, 0], ag.pos[1, 0]),
        d_min / 2,
        fill=False,
        linestyle="--",
        alpha=0.5
    )
    ax.add_patch(c)
    circles.append(c)

info_text = ax.text(0.02, 0.95, "", transform=ax.transAxes)

# --- Update function ---
def update(frame):
    u_safe_commands = {}
    
    topology.update_topology()
    
    # compute local safe control for each agent
    for agent_id in range(1, N + 1):
        ag = agents_list[agent_id - 1]

        pos = ag.pos.flatten()
        vel = ag.vel.flatten()

        u_nom_i = -k1 * (pos - ag.target) - k2 * vel

        neighbor_list = topology.get_neighbors(agent_id)  # keep 1-based ids

        u_safe_i = cbf_filter.compute_safe_control(
            agent_i=ag,
            agent_id=agent_id,
            all_agents=agents_list,
            neighbor_list=neighbor_list,
            u_nom_i=u_nom_i.reshape(2, 1)
        )

        u_safe_commands[agent_id] = u_safe_i.flatten()

    # physics update
    for agent_id in range(1, N + 1):
        ag = agents_list[agent_id - 1]
        ag.update_physics(u_safe_commands[agent_id], dt)

        history[agent_id - 1].append(ag.pos.flatten().copy())
        traj = np.array(history[agent_id - 1])

        x = ag.pos[0, 0]
        y = ag.pos[1, 0]

        points[agent_id - 1].set_data([x], [y])
        trails[agent_id - 1].set_data(traj[:, 0], traj[:, 1])
        circles[agent_id - 1].center = (x, y)

    info_text.set_text(f"Time: {frame * dt:.1f}s")
    return points + trails + circles + [info_text]

# --- Render video ---
total_frames = int(T_max / dt)
ani = FuncAnimation(fig, update, frames=total_frames, blit=True)

writer = FFMpegWriter(fps=int(1 / dt), bitrate=2000)
ani.save("decentralized_cbf_validation.mp4", writer=writer)

plt.close(fig)

print("Video saved: decentralized_cbf_validation.mp4")
# Out:
# Warning: Safety violated! Slack: 0.7838
# Warning: Safety violated! Slack: 0.7838
# Warning: Safety violated! Slack: 18.9095
# Warning: Safety violated! Slack: 18.9078
# Warning: Safety violated! Slack: 31.9816
# Warning: Safety violated! Slack: 31.9796
# Warning: Safety violated! Slack: 14.7733
# Warning: Safety violated! Slack: 40.8833
# Warning: Safety violated! Slack: 40.8948
# Warning: Safety violated! Slack: 41.6392
# Warning: Safety violated! Slack: 46.2046
# Warning: Safety violated! Slack: 46.2916
# Warning: Safety violated! Slack: 63.5978
# Warning: Safety violated! Slack: 48.3361
# Warning: Safety violated! Slack: 48.6362
# Warning: Safety violated! Slack: 82.4974
# Warning: Safety violated! Slack: 19.8210
# Warning: Safety violated! Slack: 47.5459
# Warning: Safety violated! Slack: 48.2543
# Warning: Safety violated! Slack: 98.5197
# Warning: Safety violated! Slack: 40.7860
# Warning: Safety violated! Slack: 44.1269
# Warning: Safety violated! Slack: 45.3484
# Warning: Safety violated! Slack: 111.8120
# Warning: Safety violated! Slack: 57.2444
# Warning: Safety violated! Slack: 38.3546
# Warning: Safety violated! Slack: 0.8980
# Warning: Safety violated! Slack: 0.9435
# Warning: Safety violated! Slack: 40.1457
# Warning: Safety violated! Slack: 121.3806
# Warning: Safety violated! Slack: 69.5011
# Warning: Safety violated! Slack: 30.4597
# Warning: Safety violated! Slack: 1.8894
# Warning: Safety violated! Slack: 1.9655
# Warning: Safety violated! Slack: 32.9040
# Warning: Safety violated! Slack: 126.9838
# Warning: Safety violated! Slack: 77.7903
# Warning: Safety violated! Slack: 20.6159
# Warning: Safety violated! Slack: 2.1639
# Warning: Safety violated! Slack: 2.2790
# Warning: Safety violated! Slack: 23.7958
# Warning: Safety violated! Slack: 128.7488
# Warning: Safety violated! Slack: 82.2800
# Warning: Safety violated! Slack: 8.9590
# Warning: Safety violated! Slack: 1.7573
# Warning: Safety violated! Slack: 1.9196
# Warning: Safety violated! Slack: 12.9502
# Warning: Safety violated! Slack: 126.7529
# Warning: Safety violated! Slack: 83.0719
# Warning: Safety violated! Slack: 0.6901
# Warning: Safety violated! Slack: 0.9081
# Warning: Safety violated! Slack: 0.4731
# Warning: Safety violated! Slack: 121.0224
# Warning: Safety violated! Slack: 80.1960
# Warning: Safety violated! Slack: 111.5279
# Warning: Safety violated! Slack: 73.6178
# Warning: Safety violated! Slack: 98.1746
# Warning: Safety violated! Slack: 63.3261
# Warning: Safety violated! Slack: 80.8264
# Warning: Safety violated! Slack: 49.2307
# Warning: Safety violated! Slack: 59.3283
# Warning: Safety violated! Slack: 31.1900
# Warning: Safety violated! Slack: 33.0868
# Warning: Safety violated! Slack: 8.8903
# Warning: Safety violated! Slack: 1.8713
# Warning: Safety violated! Slack: 6.8680
# Warning: Safety violated! Slack: 5.0242
# Warning: Safety violated! Slack: 16.2930
# Warning: Safety violated! Slack: 13.9992
# Warning: Safety violated! Slack: 24.0917
# Warning: Safety violated! Slack: 21.7752
# Warning: Safety violated! Slack: 30.5356
# Warning: Safety violated! Slack: 28.4486
# Warning: Safety violated! Slack: 35.8331
# Warning: Safety violated! Slack: 34.1134
# Warning: Safety violated! Slack: 40.1496
# Warning: Safety violated! Slack: 38.8603
# Warning: Safety violated! Slack: 43.6200
# Warning: Safety violated! Slack: 42.7763
# Warning: Safety violated! Slack: 46.3556
# Warning: Safety violated! Slack: 45.9435
# Warning: Safety violated! Slack: 48.4490
# Warning: Safety violated! Slack: 48.4382
# Warning: Safety violated! Slack: 49.9771
# Warning: Safety violated! Slack: 3.9849
# Warning: Safety violated! Slack: 50.3429
# Warning: Safety violated! Slack: 50.8517
# Warning: Safety violated! Slack: 8.5710
# Warning: Safety violated! Slack: 51.7794
# Warning: Safety violated! Slack: 51.2748
# Warning: Safety violated! Slack: 12.5992
# Warning: Safety violated! Slack: 52.8273
# Warning: Safety violated! Slack: 51.3658
# Warning: Safety violated! Slack: 16.1193
# Warning: Safety violated! Slack: 53.5427
# Warning: Safety violated! Slack: 51.1692
# Warning: Safety violated! Slack: 19.1771
# Warning: Safety violated! Slack: 53.9726
# Warning: Safety violated! Slack: 50.7182
# Warning: Safety violated! Slack: 21.8144
# Warning: Safety violated! Slack: 54.1565
# Warning: Safety violated! Slack: 50.0367
# Warning: Safety violated! Slack: 24.0698
# Warning: Safety violated! Slack: 54.1279
# Warning: Safety violated! Slack: 49.1403
# Warning: Safety violated! Slack: 25.9779
# Warning: Safety violated! Slack: 53.9153
# Warning: Safety violated! Slack: 48.0370
# Warning: Safety violated! Slack: 27.5704
# Warning: Safety violated! Slack: 53.5425
# Warning: Safety violated! Slack: 46.7273
# Warning: Safety violated! Slack: 28.8753
# Warning: Safety violated! Slack: 53.0293
# Warning: Safety violated! Slack: 45.2039
# Warning: Safety violated! Slack: 29.9171
# Warning: Safety violated! Slack: 52.3921
# Warning: Safety violated! Slack: 43.4508
# Warning: Safety violated! Slack: 30.7171
# Warning: Safety violated! Slack: 51.6436
# Warning: Safety violated! Slack: 41.4427
# Warning: Safety violated! Slack: 31.2924
# Warning: Safety violated! Slack: 50.7932
# Warning: Safety violated! Slack: 39.1432
# Warning: Safety violated! Slack: 31.6567
# Warning: Safety violated! Slack: 49.8468
# Warning: Safety violated! Slack: 36.5043
# Warning: Safety violated! Slack: 31.8185
# Warning: Safety violated! Slack: 48.8062
# Warning: Safety violated! Slack: 33.4661
# Warning: Safety violated! Slack: 31.7817
# Warning: Safety violated! Slack: 47.6683
# Warning: Safety violated! Slack: 29.9606
# Warning: Safety violated! Slack: 31.5437
# Warning: Safety violated! Slack: 46.4240
# Warning: Safety violated! Slack: 25.9210
# Warning: Safety violated! Slack: 31.0949
# Warning: Safety violated! Slack: 45.0552
# Warning: Safety violated! Slack: 21.3016
# Warning: Safety violated! Slack: 30.4182
# Warning: Safety violated! Slack: 43.5343
# Warning: Safety violated! Slack: 16.1106
# Warning: Safety violated! Slack: 29.4986
# Warning: Safety violated! Slack: 41.8351
# Warning: Safety violated! Slack: 10.4479
# Warning: Safety violated! Slack: 28.4178
# Warning: Safety violated! Slack: 40.0877
# Warning: Safety violated! Slack: 4.5225
# Warning: Safety violated! Slack: 30.3532
# Warning: Safety violated! Slack: 43.6192
# Warning: Safety violated! Slack: 9.1523
# Warning: Safety violated! Slack: 17.3178
# Warning: Safety violated! Slack: 13.2417
# Warning: Safety violated! Slack: 6.6071
# Warning: Safety violated! Slack: 30.6771
# Warning: Safety violated! Slack: 28.5259
# Warning: Safety violated! Slack: 2.4456
# Warning: Safety violated! Slack: 74.6872
# Warning: Safety violated! Slack: 20.7982
# Warning: Safety violated! Slack: 9.9911
# Warning: Safety violated! Slack: 1.3574
# Warning: Safety violated! Slack: 3.3949
# Warning: Safety violated! Slack: 20081097.1547
# Warning: Safety violated! Slack: 20081097.1547
# Warning: Safety violated! Slack: 2.2998
# Warning: Safety violated! Slack: 57.1644
# Warning: Safety violated! Slack: 6.8172
# Warning: Safety violated! Slack: 6.1167
# Warning: Safety violated! Slack: 5.8936
# Warning: Safety violated! Slack: 5.8401
# Warning: Safety violated! Slack: 1.2220
# Warning: Safety violated! Slack: 5.7492
# Warning: Safety violated! Slack: 2.6573
# Warning: Safety violated! Slack: 5.6324
# Warning: Safety violated! Slack: 3.5431
# Warning: Safety violated! Slack: 5.5056
# Warning: Safety violated! Slack: 4.0548
# Warning: Safety violated! Slack: 5.3679
# Warning: Safety violated! Slack: 4.3153
# Warning: Safety violated! Slack: 5.2161
# Warning: Safety violated! Slack: 4.4063
# Warning: Safety violated! Slack: 5.0475
# Warning: Safety violated! Slack: 4.3817
# Warning: Safety violated! Slack: 4.8606
# Warning: Safety violated! Slack: 4.2772
# Warning: Safety violated! Slack: 4.6552
# Warning: Safety violated! Slack: 4.1169
# Warning: Safety violated! Slack: 4.4319
# Warning: Safety violated! Slack: 3.9171
# Warning: Safety violated! Slack: 4.1922
# Warning: Safety violated! Slack: 3.6897
# Warning: Safety violated! Slack: 3.9381
# Warning: Safety violated! Slack: 3.4430
# Warning: Safety violated! Slack: 3.6721
# Warning: Safety violated! Slack: 3.1834
# Warning: Safety violated! Slack: 3.3965
# Warning: Safety violated! Slack: 2.9157
# Warning: Safety violated! Slack: 3.1140
# Warning: Safety violated! Slack: 2.6440
# Warning: Safety violated! Slack: 2.8272
# Warning: Safety violated! Slack: 2.3713
# Warning: Safety violated! Slack: 2.5384
# Warning: Safety violated! Slack: 2.1004
# Warning: Safety violated! Slack: 2.2498
# Warning: Safety violated! Slack: 1.8333
# Warning: Safety violated! Slack: 1.9637
# Warning: Safety violated! Slack: 1.5721
# Warning: Safety violated! Slack: 1.6817
# Warning: Safety violated! Slack: 1.3181
# Warning: Safety violated! Slack: 1.3720
# Warning: Safety violated! Slack: 1.0718
# Warning: Safety violated! Slack: 1.0232
# Warning: Safety violated! Slack: 0.8321
# Warning: Safety violated! Slack: 0.6385
# Warning: Safety violated! Slack: 0.5964
# Warning: Safety violated! Slack: 0.2109
# Warning: Safety violated! Slack: 0.3614
# Warning: Safety violated! Slack: 0.1289
# Warning: Safety violated! Slack: 2.0372
# Warning: Safety violated! Slack: 3.3706
# Warning: Safety violated! Slack: 4.5360
# Warning: Safety violated! Slack: 5.5369
# Warning: Safety violated! Slack: 6.3795
# Warning: Safety violated! Slack: 7.0714
# Warning: Safety violated! Slack: 7.6211
# Warning: Safety violated! Slack: 8.0319
# Warning: Safety violated! Slack: 8.3060
# Warning: Safety violated! Slack: 8.4553
# Warning: Safety violated! Slack: 8.4908
# Warning: Safety violated! Slack: 8.4230
# Warning: Safety violated! Slack: 8.2616
# Warning: Safety violated! Slack: 8.0159
# Warning: Safety violated! Slack: 7.6946
# Warning: Safety violated! Slack: 7.2968
# Warning: Safety violated! Slack: 6.8199
# Warning: Safety violated! Slack: 6.2731
# Warning: Safety violated! Slack: 5.6667
# Warning: Safety violated! Slack: 5.0113
# Warning: Safety violated! Slack: 4.3175
# Warning: Safety violated! Slack: 3.5957
# Warning: Safety violated! Slack: 2.8555
# Warning: Safety violated! Slack: 2.1051
# Warning: Safety violated! Slack: 1.3517
# Warning: Safety violated! Slack: 0.6008
# Video saved: decentralized_cbf_validation.mp4

# %% [markdown]
# ## Relax Distributed CBF

# %%
gamma = 0.8
d_min = 0.5

# State format: [x, y, vx, vy]
x_agent0  = [0.0,  0.0,  0.0, 0.0]
x_obs0    = [5.0, -0.05, 0.0, 0.0]
x_target  = np.array([10.0, 0.0, 0.0, 0.0], dtype=float)

alpha_agent = 6.0
alpha_obs   = 0.0   # static obstacle

# --- Create agents using your Agent class ---
# f_target is not used in this experiment, so set it to zeros
agent = Agent(agent_id=1, x0=x_agent0, f_target=[0, 0, 0, 0], alpha=alpha_agent)
obs   = Agent(agent_id=2, x0=x_obs0,   f_target=[0, 0, 0, 0], alpha=alpha_obs)

all_agents = [agent, obs]

# Save initial states if you want history from t=0
for ag in all_agents:
    ag.save_history()

# --- Create topology ---
# Agent and obstacle are connected so CBF checks safety constraint between them
adj = np.array([
    [0, 1],
    [1, 0]
], dtype=float)

topology = Topology(num_agents=2, adjacency_matrix=adj)
topology.plot()

# --- Create CBF filter ---
cbf_filter = DecentralizedCBF(gamma=gamma, safety_dis=d_min)

# %%
# --- History buffers ---
robot_history = []
u_hat_history = []
u_safe_history = []
h_history = []
dist_history = []

T = 15.0
dt = 0.1
steps = int(T / dt)

for k in range(steps):
    # Current robot state
    x_agent = agent.state.flatten()

    # 1) Nominal controller (PD-like tracking to target)
    u_hat = -1.5 * (agent.pos.flatten() - x_target[0:2]) - 2.5 * agent.vel.flatten()
    
    neighbor_list = topology.get_neighbors(1)
    
    # 3. Filter via Decentralized CBF
    # Only solves the QP for agent 1 locally
    u_nom_i = u_hat.reshape(2, 1)
    u_apply = cbf_filter.compute_relax_safe_control(agent, 1, all_agents, neighbor_list, u_nom_i)
    u_apply = u_apply.flatten()

    # 4) Update physics
    # robot moves with safe input
    agent.update_physics(u_apply, dt)

    # obstacle stays fixed
    obs.update_physics([0.0, 0.0], dt)

    # 5) Store histories
    robot_history.append(agent.state.flatten())
    u_hat_history.append(u_hat.copy())
    u_safe_history.append(u_apply.copy())

    # Optional diagnostics: current distance and barrier-like quantity
    dp = agent.pos - obs.pos
    dv = agent.vel - obs.vel
    dist = max(np.linalg.norm(dp), 1e-6)
    dist_history.append(dist)

    # Avoid sqrt of negative when dist < d_min
    margin = max(dist - d_min, 1e-6)
    term_safe_v = np.sqrt(2 * (agent.alpha + obs.alpha) * margin)
    h_val = term_safe_v + float((dp.T @ dv).item()) / dist
    
    h_history.append(h_val)

# --- Convert histories to arrays ---
robot_history = np.array(robot_history)
u_hat_history = np.array(u_hat_history)
u_safe_history = np.array(u_safe_history)
dist_history = np.array(dist_history)
h_history = np.array(h_history)
time = np.arange(steps) * dt

# --- Plotting ---
fig = plt.figure(figsize=(12, 12))

# 1. Trajectory
ax1 = plt.subplot(3, 1, 1)
ax1.plot(robot_history[:, 0], robot_history[:, 1], '-o', markersize=3, label='Robot path')
ax1.scatter([x_obs0[0]], [x_obs0[1]], color='red', s=100, label='Obstacle', zorder=5)
ax1.scatter([x_target[0]], [x_target[1]], color='green', s=100, marker='*', label='Target', zorder=5)
circle = plt.Circle((x_obs0[0], x_obs0[1]), d_min, color='red', fill=False, linestyle='--', label='Safety radius')
ax1.add_patch(circle)
ax1.set_title("Movement Trajectory (ZCBF Avoidance)")
ax1.set_xlabel("X (m)")
ax1.set_ylabel("Y (m)")
ax1.axis("equal")
ax1.grid(True)
ax1.legend()

# 2. Control signals
ax2 = plt.subplot(3, 2, 3)
ax2.plot(time, u_hat_history[:, 0], '--', color='gray', label='u_nom x')
ax2.plot(time, u_safe_history[:, 0], '-', color='blue', label='u_safe x')
ax2.set_title("X-axis Acceleration")
ax2.set_xlabel("Time (s)")
ax2.set_ylabel(r"$m/s^2$")
ax2.grid(True)
ax2.legend()

ax3 = plt.subplot(3, 2, 4)
ax3.plot(time, u_hat_history[:, 1], '--', color='gray', label='u_nom y')
ax3.plot(time, u_safe_history[:, 1], '-', color='green', label='u_safe y')
ax3.set_title("Y-axis Acceleration")
ax3.set_xlabel("Time (s)")
ax3.set_ylabel(r"$m/s^2$")
ax3.grid(True)
ax3.legend()

# 3. Distance to obstacle
ax4 = plt.subplot(3, 2, 5)
ax4.plot(time, dist_history, label='distance')
ax4.axhline(d_min, linestyle='--', color='red', label='d_min')
ax4.set_title("Distance to Obstacle")
ax4.set_xlabel("Time (s)")
ax4.set_ylabel("Distance (m)")
ax4.grid(True)
ax4.legend()

# 4. h_ij evolution
ax5 = plt.subplot(3, 2, 6)
ax5.plot(time, h_history, label=r'$h_{ij}$')
ax5.axhline(0.0, linestyle='--', color='red', label='0')
ax5.set_title("Barrier Function Value")
ax5.set_xlabel("Time (s)")
ax5.set_ylabel(r"$h_{ij}$")
ax5.grid(True)
ax5.legend()

plt.tight_layout()
plt.show()

# %%
# --- Simulation Configuration ---
N = 19
R_circle = 150
dt = 0.05
T_max = 90
steps = int(T_max / dt)

gamma = 1e-3
d_min = 18.0
k1, k2 = 0.05, 0.4

alpha_val = 10.0
beta_val = 20.0

# --- Create agents using your Agent class ---
agents_list = []

for i in range(N):
    angle = 2 * np.pi * i / N

    # Initial state: [x, y, vx, vy]
    x0 = [
        R_circle * np.cos(angle),
        R_circle * np.sin(angle),
        0.0,
        0.0
    ]

    # Opposite-side target
    target_pos = -np.array(x0[0:2]) -6

    # f_target is not used in this experiment
    ag = Agent(
        agent_id=i + 1,
        x0=x0,
        f_target=[0.0, 0.0, 0.0, 0.0],
        alpha=alpha_val,
        beta=beta_val
    )

    # attach target for this experiment
    ag.target = target_pos.reshape(2,)
    agents_list.append(ag)

# --- Dynamics topology ---
topology = CBFTopology(agents_list, d_min, gamma)
topology._compute_neighborhood_radii()

topology.plot(show_radius= False)

# --- CBF filter ---
cbf_filter = DecentralizedCBF(gamma=gamma,k= 1, safety_dis=d_min)
deadlock_manager = DeadlockManager(zero_tol=5e-3, lp_tol=1e-7)

# %%
# --- History ---
history = [[] for _ in range(N)]
u_nom_hist = [[] for _ in range(N)]
u_safe_hist = [[] for _ in range(N)]
atvc = []

# --- Simulation Loop ---
for t in range(steps):
    u_nom_commands = {}
    u_safe_commands = {}
    
    topology.update_topology()

    # 1) Compute local safe control for each agent
    for agent_id in range(1, N + 1):
        current_agent = agents_list[agent_id - 1]   # because list is 0-based

        pos = current_agent.pos.flatten()
        vel = current_agent.vel.flatten()

        u_nom_i = -k1 * (pos - current_agent.target) - k2 * vel

        neighbor_list = topology.get_neighbors(agent_id)   # keep 1-based IDs

        u_safe_i = cbf_filter.compute_relax_safe_control(
            agent_i=current_agent,
            agent_id=agent_id,
            all_agents=agents_list,        # list ordered by id
            neighbor_list=neighbor_list,
            u_nom_i=u_nom_i.reshape(2, 1)
        )
        
        A, b, n_active_constraints = cbf_filter.compute_constraint(agent_i = current_agent, agent_id = agent_id, all_agents = agents_list, neighbor_list = neighbor_list, u_i = u_safe_i)
        
        u_final, deadlock_type = deadlock_manager.resolve_deadlock(
            cbf_solver=cbf_filter,
            agent_i=current_agent,
            agent_id=agent_id,
            all_agents=agents_list,
            neighbor_list=neighbor_list,
            u_nom_i=u_nom_i,
            u_safe_i=u_safe_i,
            debug_type2=True
        )

        # if deadlock_type:
        #     print(f"Deadlock {deadlock_type} detected for agent {agent_id} at time {t*dt:.2f}s. Resolving...")
        #     print("===========================================")
            
        u_nom_commands[agent_id] = u_nom_i.copy()
        u_safe_commands[agent_id] = u_final.flatten()

    # 2) Update physics
    for agent_id in range(1, N + 1):
        ag = agents_list[agent_id - 1]

        ag.update_physics(u_safe_commands[agent_id], dt)

        history[agent_id - 1].append(ag.pos.flatten().copy())
        u_nom_hist[agent_id - 1].append(u_nom_commands[agent_id].copy())
        u_safe_hist[agent_id - 1].append(u_safe_commands[agent_id].copy())

# --- Convert history to arrays ---
history = [np.array(h) for h in history]
u_nom_hist = [np.array(h) for h in u_nom_hist]
u_safe_hist = [np.array(h) for h in u_safe_hist]

# --- Plot trajectories ---
plt.figure(figsize=(8, 8))
for i in range(N):
    traj = history[i]
    if len(traj) == 0:
        continue

    plt.plot(traj[:, 0], traj[:, 1], alpha=0.7, label=f'Agent {i+1}')
    plt.scatter(traj[0, 0], traj[0, 1], marker='o')
    plt.scatter(traj[-1, 0], traj[-1, 1], marker='x')
    plt.scatter(agents_list[i].target[0], agents_list[i].target[1], marker='*', s=120)

plt.title(f"Robot Position Swapping with Relaxed Decentralized CBF (gamma={gamma}, d_min={d_min})")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.axis("equal")
plt.grid(True)
plt.legend()
plt.show()

# %%
# --- Plot control inputs (for debugging) ---
time = np.arange(len(u_nom_hist[0])) * dt

fig, axes = plt.subplots(N, 2, figsize=(10, 3*N))

for i in range(N):
    u_nom = u_nom_hist[i]
    u_safe = u_safe_hist[i]

    # X control
    axes[i,0].plot(time, u_nom[:,0], '--', label='u_nom_x')
    axes[i,0].plot(time, u_safe[:,0], '-', label='u_safe_x')
    axes[i,0].set_title(f'Agent {i} - X acceleration')
    axes[i,0].set_xlabel('Time (s)')
    axes[i,0].set_ylabel('Acceleration')
    axes[i,0].grid(True)
    axes[i,0].legend()

    # Y control
    axes[i,1].plot(time, u_nom[:,1], '--', label='u_nom_y')
    axes[i,1].plot(time, u_safe[:,1], '-', label='u_safe_y')
    axes[i,1].set_title(f'Agent {i} - Y acceleration')
    axes[i,1].set_xlabel('Time (s)')
    axes[i,1].set_ylabel('Acceleration')
    axes[i,1].grid(True)
    axes[i,1].legend()

plt.tight_layout()
plt.show()

# %%
from matplotlib.animation import FFMpegWriter, FuncAnimation

# --- Animation figure ---
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlim(-R_circle - 50, R_circle + 50)
ax.set_ylim(-R_circle - 50, R_circle + 50)
ax.set_aspect("equal")
ax.grid(True)
ax.set_title(f"{N} Robot Swapping - Relax Decentralized CBF (gamma={gamma}, d_min={d_min})")

# plot targets
for i in range(N):
    ax.scatter(
        agents_list[i].target[0],
        agents_list[i].target[1],
        marker="x",
        color="red",
        s=100
    )

points = [ax.plot([], [], "o", ms=10)[0] for _ in range(N)]
trails = [ax.plot([], [], alpha=0.3, lw=1.5)[0] for _ in range(N)]

# safety circles
circles = []
for i in range(N):
    c = plt.Circle(
        (history[i][0, 0], history[i][0, 1]),
        d_min / 2,
        fill=False,
        linestyle="--",
        alpha=0.5
    )
    ax.add_patch(c)
    circles.append(c)

info_text = ax.text(0.02, 0.95, "", transform=ax.transAxes)

# --- Update function ---
def update(frame):
    for i in range(N):
        traj = history[i]

        x = traj[frame, 0]
        y = traj[frame, 1]

        points[i].set_data([x], [y])
        trails[i].set_data(traj[:frame + 1, 0], traj[:frame + 1, 1])
        circles[i].center = (x, y)

    info_text.set_text(f"Time: {frame * dt:.1f}s")

    return points + trails + circles + [info_text]

# --- Render video ---
total_frames = min(len(h) for h in history)

ani = FuncAnimation(
    fig,
    update,
    frames=total_frames,
    blit=True
)

writer = FFMpegWriter(
    fps=int(1 / dt),
    bitrate=2000
)

ani.save(
    "../media/relax_decentralized_cbf_validation.mp4",
    writer=writer
)

plt.close(fig)

print("Video saved: relax_decentralized_cbf_validation.mp4")
# Out:
# Video saved: relax_decentralized_cbf_validation.mp4

# %%
from matplotlib.animation import FFMpegWriter, FuncAnimation

# --- Reinitialize agents ---
agents_list = []
history = [[] for _ in range(N)]

for i in range(N):
    angle = 2 * np.pi * i / N

    x0 = [
        R_circle * np.cos(angle),
        R_circle * np.sin(angle),
        0.0,
        0.0
    ]

    target = -np.array(x0[0:2])

    # agent_id must be 1-based for your DecentralizedCBF
    ag = Agent(i + 1, x0, [0, 0, 0, 0], alpha=alpha_val, beta=beta_val)
    ag.target = target
    agents_list.append(ag)

# --- Dynamics topology ---
topology = CBFTopology(agents_list, d_min, gamma)
topology._compute_neighborhood_radii()

# --- Decentralized CBF filter ---
cbf_filter = DecentralizedCBF(gamma=gamma, safety_dis=d_min)

# --- Reinitialize deadlock manager ---
deadlock_manager = DeadlockManager(zero_tol=1e-3, lp_tol=1e-7)

# --- Animation figure ---
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlim(-R_circle - 50, R_circle + 50)
ax.set_ylim(-R_circle - 50, R_circle + 50)
ax.set_aspect("equal")
ax.grid(True)
ax.set_title(f"{N} Robot Swapping - Relax Deu_safe_icentralized CBF (gamma={gamma}, d_min={d_min})")

# plot targets
for ag in agents_list:
    ax.scatter(ag.target[0], ag.target[1], marker="x", color="red", s=100)

points = [ax.plot([], [], "o", ms=10)[0] for _ in range(N)]
trails = [ax.plot([], [], alpha=0.3, lw=1.5)[0] for _ in range(N)]

# safety circles
circles = []
for ag in agents_list:
    c = plt.Circle(
        (ag.pos[0, 0], ag.pos[1, 0]),
        d_min / 2,
        fill=False,
        linestyle="--",
        alpha=0.5
    )
    ax.add_patch(c)
    circles.append(c)

info_text = ax.text(0.02, 0.95, "", transform=ax.transAxes)

# --- Update function ---
def update(frame):
    u_safe_commands = {}

    topology.update_topology()

    # compute local safe control for each agent
    for agent_id in range(1, N + 1):
        ag = agents_list[agent_id - 1]

        pos = ag.pos.flatten()
        vel = ag.vel.flatten()

        u_nom_i = -k1 * (pos - ag.target) - k2 * vel

        neighbor_list = topology.get_neighbors(agent_id)  # keep 1-based ids

        u_safe_i = cbf_filter.compute_relax_safe_control(
            agent_i=ag,
            agent_id=agent_id,
            all_agents=agents_list,
            neighbor_list=neighbor_list,
            u_nom_i=u_nom_i.reshape(2, 1)
        )

        u_final, deadlock_type = deadlock_manager.resolve_deadlock(
            cbf_solver=cbf_filter,
            agent_i=ag,
            agent_id=agent_id,
            all_agents=agents_list,
            neighbor_list=neighbor_list,
            u_nom_i=u_nom_i,
            u_safe_i=u_safe_i,
            debug_type2=True
        )

        # if deadlock_type:
        #     print(f"Deadlock {deadlock_type} detected for agent {agent_id} at time {frame*dt:.2f}s. Resolving...")
        #     print("===========================================")

        u_safe_commands[agent_id] = u_final.flatten()

    # physics update
    for agent_id in range(1, N + 1):
        ag = agents_list[agent_id - 1]

        ag.update_physics(u_safe_commands[agent_id], dt)

        history[agent_id - 1].append(ag.pos.flatten().copy())
        traj = np.array(history[agent_id - 1])

        x = ag.pos[0, 0]
        y = ag.pos[1, 0]

        points[agent_id - 1].set_data([x], [y])
        trails[agent_id - 1].set_data(traj[:, 0], traj[:, 1])
        circles[agent_id - 1].center = (x, y)

    info_text.set_text(f"Time: {frame * dt:.1f}s")
    return points + trails + circles + [info_text]

# --- Render video ---
total_frames = int(T_max / dt)
ani = FuncAnimation(fig, update, frames=total_frames, blit=True)

writer = FFMpegWriter(fps=int(1 / dt), bitrate=2000)
ani.save("../media/relax_decentralized_cbf_validation.mp4", writer=writer)

plt.close(fig)

print("Video saved: relax_decentralized_cbf_validation.mp4")
# Out:
# Video saved: relax_decentralized_cbf_validation.mp4
